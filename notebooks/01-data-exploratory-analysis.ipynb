# %% [markdown]
# # Import des librairies

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import LinearSVC
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# # Import des datasets

# %%
# Load the datasets
pokemon = pd.read_csv("/home/marmouset/Documents/api_model/data/raw/pokemon.csv")  # Pokemon Dataset
pokemon = pokemon.rename(index=str, columns={"#": "Number"})
combats = pd.read_csv("/home/marmouset/Documents/api_model/data/raw/combats.csv")  # Combats Dataset
tests = pd.read_csv("/home/marmouset/Documents/api_model/data/raw/tests.csv")  # Test Dataset
prediction_df = tests.copy()

# %%
pokemon.head()
# Out:
#    Number           Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0       1      Bulbasaur  Grass  Poison  45      49       49       65
# 1       2        Ivysaur  Grass  Poison  60      62       63       80
# 2       3       Venusaur  Grass  Poison  80      82       83      100
# 3       4  Mega Venusaur  Grass  Poison  80     100      123      122
# 4       5     Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
type(tests)
# Out:
# pandas.core.frame.DataFrame

# %%
combats.head()
# Out:
#    First_pokemon  Second_pokemon  Winner
# 0            266             298     298
# 1            702             701     701
# 2            191             668     668
# 3            237             683     683
# 4            151             231     151

# %% [markdown]
# # Analyse du dataset

# %% [markdown]
# ### Généralités

# %%
# Shape of the datasets
print("Shape of Pokemon dataset : " + str(pokemon.shape))
print("Shape of Combats dataset: " + str(combats.shape))
# Out:
# Shape of Pokemon dataset : (800, 12)
# Shape of Combats dataset: (50000, 3)

# %%
# Check of missing values
print(pokemon.isnull().sum())
# Out:
# Number          0
# Name            1
# Type 1          0
# Type 2        386
# HP              0
# Attack          0
# Defense         0
# Sp. Atk         0
# Sp. Def         0
# Speed           0
# Generation      0
# Legendary       0
# dtype: int64

# %%
combats.isnull().sum()
# Out:
# First_pokemon     0
# Second_pokemon    0
# Winner            0
# dtype: int64

# %%
# Let's check out the row where a Pokemon name is missing
print(pokemon[pokemon['Name'].isnull()])
print("This pokemon is before the missing Pokemon: " + pokemon['Name'][61])
print("This pokemon is after the missing Pokemon: " + pokemon['Name'][63])
# Out:
#     Number Name    Type 1 Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 62      63  NaN  Fighting    NaN  65     105       60       60       70
#
#     Speed  Generation  Legendary
# 62     95           1      False
# This pokemon is before the missing Pokemon: Mankey
# This pokemon is after the missing Pokemon: Growlithe

# %%
pokemon['Name'][62] = "Primeape"
# Out:
# /tmp/ipykernel_48676/1906487552.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pokemon['Name'][62] = "Primeape"

# %% [markdown]
# ### Ajout de colonnes pour l'analyse

# %%
# Column 'Total_stats" : sum of all the Pokemon stats
pokemon['Total_stats'] = pokemon['HP'] + pokemon['Attack'] + pokemon['Defense'] + pokemon['Sp. Atk'] + pokemon['Sp. Def'] + pokemon['Speed']
pokemon
# Out:
#      Number            Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0         1       Bulbasaur    Grass  Poison  45      49       49       65
# 1         2         Ivysaur    Grass  Poison  60      62       63       80
# 2         3        Venusaur    Grass  Poison  80      82       83      100
# 3         4   Mega Venusaur    Grass  Poison  80     100      123      122
# 4         5      Charmander     Fire     NaN  39      52       43       60
# ..      ...             ...      ...     ...  ..     ...      ...      ...
# 795     796         Diancie     Rock   Fairy  50     100      150      100
# 796     797    Mega Diancie     Rock   Fairy  50     160      110      160
# 797     798  Hoopa Confined  Psychic   Ghost  80     110       60      150
# 798     799   Hoopa Unbound  Psychic    Dark  80     160       60      170
# 799     800       Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary  Total_stats
# 0         65     45           1      False          318
# 1         80     60           1      False          405
# 2        100     80           1      False          525
# 3        120     80           1      False          625
# 4         50     65           1      False          309
# ..       ...    ...         ...        ...          ...
# 795      150     50           6       True          600
# 796      110    110           6       True          700
# 797      130     70           6       True          600
# 798      130     80           6       True          680
# 799       90     70           6       True          600
#
# [800 rows x 13 columns]

# %% [markdown]
# # Analyse exploratoire de la data

# %% [markdown]
# ### Analyse des victoires de chaque Pokémon

# %%
# Calculate the win % of each pokemon 
# Add the calculation to the pokemon dataset 
total_Wins = combats.Winner.value_counts()

# Get the number of wins for each pokemon
numberOfWins = combats.groupby('Winner').count()

# Both methods produce the same results
countByFirst = combats.groupby('Second_pokemon').count()
countBySecond = combats.groupby('First_pokemon').count()
print("Looking at the dimensions of our dataframes")
print("Count by first winner shape: " + str(countByFirst.shape))
print("Count by second winner shape: " + str(countBySecond.shape))
print("Total Wins shape : " + str(total_Wins.shape))
# Out:
# Looking at the dimensions of our dataframes
# Count by first winner shape: (784, 2)
# Count by second winner shape: (784, 2)
# Total Wins shape : (783,)

# %%
find_losing_pokemon= np.setdiff1d(countByFirst.index.values, numberOfWins.index.values)-1 #offset because the index and number are off by one
print(find_losing_pokemon)
losing_pokemon = pokemon.iloc[find_losing_pokemon[0],]
print(losing_pokemon)
# Out:
# [230]
# Number             231
# Name           Shuckle
# Type 1             Bug
# Type 2            Rock
# HP                  20
# Attack              10
# Defense            230
# Sp. Atk             10
# Sp. Def            230
# Speed                5
# Generation           2
# Legendary        False
# Total_stats        505
# Name: 230, dtype: object

# %%
numberOfWins = numberOfWins.sort_index()
numberOfWins['Total Fights'] = countByFirst.Winner + countBySecond.Winner
numberOfWins['Win Percentage']= numberOfWins.First_pokemon/numberOfWins['Total Fights']

# merge the winning dataset and the original pokemon dataset
results2 = pd.merge(pokemon, numberOfWins, right_index = True, left_on='Number')
results = pd.merge(pokemon, numberOfWins, left_on='Number', right_index = True, how='left')

results
# Out:
#      Number            Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0         1       Bulbasaur    Grass  Poison  45      49       49       65
# 1         2         Ivysaur    Grass  Poison  60      62       63       80
# 2         3        Venusaur    Grass  Poison  80      82       83      100
# 3         4   Mega Venusaur    Grass  Poison  80     100      123      122
# 4         5      Charmander     Fire     NaN  39      52       43       60
# ..      ...             ...      ...     ...  ..     ...      ...      ...
# 795     796         Diancie     Rock   Fairy  50     100      150      100
# 796     797    Mega Diancie     Rock   Fairy  50     160      110      160
# 797     798  Hoopa Confined  Psychic   Ghost  80     110       60      150
# 798     799   Hoopa Unbound  Psychic    Dark  80     160       60      170
# 799     800       Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary  Total_stats  First_pokemon  \
# 0         65     45           1      False          318           37.0
# 1         80     60           1      False          405           46.0
# 2        100     80           1      False          525           89.0
# 3        120     80           1      False          625           70.0
# 4         50     65           1      False          309           55.0
# ..       ...    ...         ...        ...          ...            ...
# 795      150     50           6       True          600           39.0
# 796      110    110           6       True          700          116.0
# 797      130     70           6       True          600           60.0
# 798      130     80           6       True          680           89.0
# 799       90     70           6       True          600           75.0
#
#      Second_pokemon  Total Fights  Win Percentage
# 0              37.0         133.0        0.278195
# 1              46.0         121.0        0.380165
# 2              89.0         132.0        0.674242
# 3              70.0         125.0        0.560000
# 4              55.0         112.0        0.491071
# ..              ...           ...             ...
# 795            39.0         105.0        0.371429
# 796           116.0         131.0        0.885496
# 797            60.0         119.0        0.504202
# 798            89.0         144.0        0.618056
# 799            75.0         121.0        0.619835
#
# [800 rows x 17 columns]

# %%
# We can look at the difference between the two datasets to see which pokemon never recorded a fight
results[results['Win Percentage'].isnull()]
# Out:
#      Number                  Name    Type 1   Type 2   HP  Attack  Defense  \
# 11       12             Blastoise     Water      NaN   79      83      100
# 32       33             Sandshrew    Ground      NaN   50      75       85
# 45       46            Wigglytuff    Normal    Fairy  140      70       45
# 65       66               Poliwag     Water      NaN   40      50       40
# 77       78            Victreebel     Grass   Poison   80     105       65
# 89       90              Magneton  Electric    Steel   50      60       95
# 143     144                 Ditto    Normal      NaN   48      48       48
# 182     183               Ariados       Bug   Poison   70      90       70
# 230     231               Shuckle       Bug     Rock   20      10      230
# 235     236              Ursaring    Normal      NaN   90     130       75
# 321     322              Hariyama  Fighting      NaN  144     120       60
# 418     419           Mega Latias    Dragon  Psychic   80     100      120
# 478     479             Honchkrow      Dark   Flying  100     125       52
# 555     556               Servine     Grass      NaN   60      60       75
# 617     618              Maractus     Grass      NaN   75      86       67
# 654     655             Jellicent     Water    Ghost  100      60       70
# 781     782  Pumpkaboo Small Size     Ghost    Grass   44      66       70
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total_stats  \
# 11        85      105     78           1      False          530
# 32        20       30     40           1      False          300
# 45        85       50     45           1      False          435
# 65        40       40     90           1      False          300
# 77       100       70     70           1      False          490
# 89       120       70     70           1      False          465
# 143       48       48     48           1      False          288
# 182       60       60     40           2      False          390
# 230       10      230      5           2      False          505
# 235       75       75     55           2      False          500
# 321       40       60     50           3      False          474
# 418      140      150    110           3       True          700
# 478      105       52     71           4      False          505
# 555       60       75     83           5      False          413
# 617      106       67     60           5      False          461
# 654       85      105     60           5      False          480
# 781       44       55     56           6      False          335
#
#      First_pokemon  Second_pokemon  Total Fights  Win Percentage
# 11             NaN             NaN           NaN             NaN
# 32             NaN             NaN           NaN             NaN
# 45             NaN             NaN           NaN             NaN
# 65             NaN             NaN           NaN             NaN
# 77             NaN             NaN           NaN             NaN
# 89             NaN             NaN           NaN             NaN
# 143            NaN             NaN           NaN             NaN
# 182            NaN             NaN           NaN             NaN
# 230            NaN             NaN           NaN             NaN
# 235            NaN             NaN           NaN             NaN
# 321            NaN             NaN           NaN             NaN
# 418            NaN             NaN           NaN             NaN
# 478            NaN             NaN           NaN             NaN
# 555            NaN             NaN           NaN             NaN
# 617            NaN             NaN           NaN             NaN
# 654            NaN             NaN           NaN             NaN
# 781            NaN             NaN           NaN             NaN

# %%
results[np.isfinite(results['Win Percentage'])].sort_values(by = ['Win Percentage']).head(10)
# Out:
#      Number       Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 289     290    Silcoon      Bug     NaN  50      35       55       25
# 189     190     Togepi    Fairy     NaN  35      20       65       40
# 638     639    Solosis  Psychic     NaN  45      30       40      105
# 236     237     Slugma     Fire     NaN  40      40       40       70
# 576     577      Munna  Psychic     NaN  76      25       45       67
# 188     189  Igglybuff   Normal   Fairy  90      30       15       40
# 394     395     Wynaut  Psychic     NaN  95      23       48       23
# 209     210     Wooper    Water  Ground  55      45       45       25
# 291     292    Cascoon      Bug     NaN  50      35       55       25
# 752     753   Spritzee    Fairy     NaN  78      52       60       63
#
#      Sp. Def  Speed  Generation  Legendary  Total_stats  First_pokemon  \
# 289       25     15           3      False          205            3.0
# 189       65     20           2      False          245            3.0
# 638       50     20           5      False          290            4.0
# 236       40     20           2      False          250            4.0
# 576       55     24           5      False          292            5.0
# 188       20     15           2      False          210            5.0
# 394       48     23           3      False          260            6.0
# 209       25     15           2      False          210            6.0
# 291       25     15           3      False          205            7.0
# 752       65     23           6      False          341            8.0
#
#      Second_pokemon  Total Fights  Win Percentage
# 289             3.0         138.0        0.021739
# 189             3.0         122.0        0.024590
# 638             4.0         129.0        0.031008
# 236             4.0         123.0        0.032520
# 576             5.0         128.0        0.039062
# 188             5.0         115.0        0.043478
# 394             6.0         130.0        0.046154
# 209             6.0         125.0        0.048000
# 291             7.0         133.0        0.052632
# 752             8.0         133.0        0.060150

# %%
results[np.isfinite(results['Win Percentage'])].sort_values(by = ['Win Percentage'], ascending = False).head(10)
# Out:
#      Number                      Name   Type 1    Type 2   HP  Attack  \
# 154     155           Mega Aerodactyl     Rock    Flying   80     135
# 512     513                   Weavile     Dark       Ice   70     120
# 703     704    Tornadus Therian Forme   Flying       NaN   79     100
# 19       20             Mega Beedrill      Bug    Poison   65     150
# 153     154                Aerodactyl     Rock    Flying   80     105
# 476     477              Mega Lopunny   Normal  Fighting   65     136
# 726     727                  Greninja    Water      Dark   72      95
# 716     717  Meloetta Pirouette Forme   Normal  Fighting  100     128
# 164     165             Mega Mewtwo Y  Psychic       NaN  106     150
# 349     350             Mega Sharpedo    Water      Dark   70     140
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total_stats  \
# 154       85       70       95    150           1      False          615
# 512       65       45       85    125           4      False          510
# 703       80      110       90    121           5       True          580
# 19        40       15       80    145           1      False          495
# 153       65       60       75    130           1      False          515
# 476       94       54       96    135           4      False          580
# 726       67      103       71    122           6      False          530
# 716       90       77       77    128           5      False          600
# 164       70      194      120    140           1       True          780
# 349       70      110       65    105           3      False          560
#
#      First_pokemon  Second_pokemon  Total Fights  Win Percentage
# 154          127.0           127.0         129.0        0.984496
# 512          116.0           116.0         119.0        0.974790
# 703          121.0           121.0         125.0        0.968000
# 19           115.0           115.0         119.0        0.966387
# 153          136.0           136.0         141.0        0.964539
# 476          124.0           124.0         129.0        0.961240
# 726          122.0           122.0         127.0        0.960630
# 716          118.0           118.0         123.0        0.959350
# 164          119.0           119.0         125.0        0.952000
# 349          114.0           114.0         120.0        0.950000

# %% [markdown]
# ### Résumé de la donnée

# %%
results.describe()
# Out:
#          Number          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.0000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   400.5000   69.258750   79.001250   73.842500   72.820000   71.902500
# std    231.0844   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.0000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    200.7500   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    400.5000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    600.2500   80.000000  100.000000   90.000000   95.000000   90.000000
# max    800.0000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation  Total_stats  First_pokemon  Second_pokemon  \
# count  800.000000   800.00000    800.00000     783.000000      783.000000
# mean    68.277500     3.32375    435.10250      63.856960       63.856960
# std     29.060474     1.66129    119.96304      32.925941       32.925941
# min      5.000000     1.00000    180.00000       3.000000        3.000000
# 25%     45.000000     2.00000    330.00000      36.000000       36.000000
# 50%     65.000000     3.00000    450.00000      62.000000       62.000000
# 75%     90.000000     5.00000    515.00000      91.000000       91.000000
# max    180.000000     6.00000    780.00000     152.000000      152.000000
#
#        Total Fights  Win Percentage
# count    783.000000      783.000000
# mean     127.541507        0.501538
# std       11.397402        0.254993
# min       92.000000        0.021739
# 25%      120.000000        0.284228
# 50%      128.000000        0.491071
# 75%      135.000000        0.717644
# max      164.000000        0.984496

# %% [markdown]
# ### Quelques graphiques

# %% [markdown]
# ##### Nombre de Pokémon par type

# %%
sns.set_color_codes("pastel")
ax = sns.countplot(x="Type 1", hue="Legendary", data=results, order=results['Type 1'].value_counts().index)
plt.xticks(rotation= 90)
plt.xlabel('Type 1')
plt.ylabel('Total')
plt.title("Total Pokemon by Type 1")
# Out:
# Text(0.5, 1.0, 'Total Pokemon by Type 1')

# %%
ax = sns.countplot(x="Type 2", hue="Legendary", data=results, order=results['Type 2'].value_counts().index)
plt.xticks(rotation= 90)
plt.xlabel('Type 2')
plt.ylabel('Total ')
plt.title("Total Pokemon by Type 2")
# Out:
# Text(0.5, 1.0, 'Total Pokemon by Type 2')

# %% [markdown]
# ##### Répartition des Pokémon selon leur total BST

# %%
sns.distplot(pokemon.Total_stats)
plt.show()
# Out:
# /home/marmouset/Documents/api_model/env/lib/python3.10/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
mean_stats = pokemon['Total_stats'].mean()
print(mean_stats)
# Out:
# 435.1025

# %%
#closest value from mean_stats
average_pokemon = min(pokemon['Total_stats'], key=lambda x: abs(x-mean_stats))
print(pokemon.loc[((pokemon['Total_stats'] >= average_pokemon-5) & (pokemon['Total_stats'] <= average_pokemon+5)), ['Name', 'Total_stats']])
# Out:
#            Name  Total_stats
# 29        Arbok          438
# 45   Wigglytuff          435
# 58      Persian          440
# 122     Tangela          435
# 126      Seadra          440
# 210    Quagsire          430
# 215  Misdreavus          435
# 222      Gligar          430
# 227    Qwilfish          430
# 233     Sneasel          430
# 300     Swellow          430
# 302    Pelipper          430
# 312    Vigoroth          440
# 331      Lairon          430
# 369    Lunatone          440
# 370     Solrock          440
# 384     Kecleon          440
# 531       Rotom          440
# 661       Klang          440
# 772     Dedenne          431

# %%
sorted_pokemon_df = pokemon.sort_values(by='Total_stats')
#pokemon with 10 lowest stats
print(sorted_pokemon_df[['Name', 'Total_stats']].head(10))
# Out:
#            Name  Total_stats
# 206     Sunkern          180
# 322     Azurill          190
# 446   Kricketot          194
# 288     Wurmple          195
# 16       Weedle          195
# 13     Caterpie          195
# 303       Ralts          198
# 732  Scatterbug          200
# 139    Magikarp          200
# 381      Feebas          200

# %%
#pokemon with 10 highest stats
print(sorted_pokemon_df[['Name', 'Total_stats', 'Legendary']].tail(10))
# Out:
#                     Name  Total_stats  Legendary
# 413       Mega Metagross          700      False
# 409       Mega Salamence          700      False
# 494        Mega Garchomp          700      False
# 712  Kyurem White Kyurem          700       True
# 552               Arceus          720       True
# 424       Primal Groudon          770       True
# 422        Primal Kyogre          770       True
# 164        Mega Mewtwo Y          780       True
# 426        Mega Rayquaza          780       True
# 163        Mega Mewtwo X          780       True

# %%
legendary_pokemon = pokemon.loc[pokemon['Legendary'] == True]
legendary_pokemon = legendary_pokemon.sort_values(by='Total_stats')
print(legendary_pokemon[['Name', 'Total_stats']].head(20))
# Out:
#                           Name  Total_stats
# 156                   Articuno          580
# 539                      Azelf          580
# 699                   Cobalion          580
# 700                  Terrakion          580
# 701                   Virizion          580
# 702   Tornadus Incarnate Forme          580
# 703     Tornadus Therian Forme          580
# 704  Thundurus Incarnate Forme          580
# 538                    Mesprit          580
# 416                  Registeel          580
# 415                     Regice          580
# 705    Thundurus Therian Forme          580
# 158                    Moltres          580
# 157                     Zapdos          580
# 414                   Regirock          580
# 262                     Raikou          580
# 537                       Uxie          580
# 264                    Suicune          580
# 263                      Entei          580
# 794         Zygarde Half Forme          600

# %% [markdown]
# ##### Analyse des Pokémon selon leur génération

# %%
# New pokemon introduced on each generation, sort ascendingly
print(pokemon['Generation'].value_counts())

sns.countplot(x='Generation', data=pokemon, order=pokemon['Generation'].value_counts().index)
plt.show()
# Out:
# 1    166
# 5    165
# 3    160
# 4    121
# 2    106
# 6     82
# Name: Generation, dtype: int64

# %%
# Group data by generation
group_df = pokemon.drop(['Number', 'Legendary'], axis=1)
pokemon_groups = group_df.groupby('Generation')
pokemon_groups_mean = pokemon_groups.mean()

sns.pointplot(x=pokemon_groups_mean.index.values, y=pokemon_groups_mean['Total_stats'])
plt.show()

# %%
fig, axes = plt.subplots(ncols=2, nrows=3, figsize=(15, 10))
sns.pointplot(x=pokemon_groups_mean.index.values, y=pokemon_groups_mean['Attack'], color='red', ax=axes[0][0])
sns.pointplot(x=pokemon_groups_mean.index.values, y=pokemon_groups_mean['Defense'], color='blue', ax=axes[0][1])
sns.pointplot(x=pokemon_groups_mean.index.values, y=pokemon_groups_mean['HP'], color='black', ax=axes[1][0])
sns.pointplot(x=pokemon_groups_mean.index.values, y=pokemon_groups_mean['Speed'], color='green', ax=axes[1][1])
sns.pointplot(x=pokemon_groups_mean.index.values, y=pokemon_groups_mean['Sp. Atk'], color='orange', ax=axes[2][0])
sns.pointplot(x=pokemon_groups_mean.index.values, y=pokemon_groups_mean['Sp. Def'], color='purple', ax=axes[2][1])

plt.show()

# %% [markdown]
# ##### Analyse des taux de victoire des Pokémon

# %%
results.groupby('Type 1').agg({'Win Percentage':'mean'}).sort_values(by = ['Win Percentage'], ascending = False)
# Out:
#           Win Percentage
# Type 1
# Flying          0.765061
# Dragon          0.633587
# Electric        0.632861
# Dark            0.629726
# Fire            0.579215
# Psychic         0.545747
# Ground          0.541526
# Normal          0.535578
# Ghost           0.484027
# Fighting        0.475616
# Water           0.469357
# Grass           0.440364
# Ice             0.439604
# Bug             0.439006
# Poison          0.433262
# Steel           0.424529
# Rock            0.404852
# Fairy           0.329300

# %% [markdown]
# ##### Corrélation entre le taux de victoires et les statistiques des Pokémon

# %%
col = ['Type 1','HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Win Percentage']
sns.pairplot(results.loc[:,col].dropna())

# %%
g = sns.PairGrid(results.loc[:,col], diag_sharey=False)
g.map_lower(sns.kdeplot, cmap="Blues_d")
g.map_upper(sns.regplot)
g.map_diag(sns.kdeplot, lw=3)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/marmouset/Documents/api_model/notebooks/01-data-exploratory-analysis.ipynb Cellule 46 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/home/marmouset/Documents/api_model/notebooks/01-data-exploratory-analysis.ipynb#X63sZmlsZQ%3D%3D?line=0'>1</a> g = sns.PairGrid(results.loc[:,col], diag_sharey=False)
# ----> <a href='vscode-notebook-cell:/home/marmouset/Documents/api_model/notebooks/01-data-exploratory-analysis.ipynb#X63sZmlsZQ%3D%3D?line=1'>2</a> g.map_lower(sns.kdeplot, cmap="Blues_d")
#       <a href='vscode-notebook-cell:/home/marmouset/Documents/api_model/notebooks/01-data-exploratory-analysis.ipynb#X63sZmlsZQ%3D%3D?line=2'>3</a> g.map_upper(sns.regplot)
#       <a href='vscode-notebook-cell:/home/marmouset/Documents/api_model/notebooks/01-data-exploratory-analysis.ipynb#X63sZmlsZQ%3D%3D?line=3'>4</a> g.map_diag(sns.kdeplot, lw=3)
#
# File ~/Documents/api_model/env/lib/python3.10/site-packages/seaborn/axisgrid.py:1357, in PairGrid.map_lower(self, func, **kwargs)
#    1346 """Plot with a bivariate function on the lower diagonal subplots.
#    1347
#    1348 Parameters
#    (...)
#    1354
#    1355 """
#    1356 indices = zip(*np.tril_indices_from(self.axes, -1))
# -> 1357 self._map_bivariate(func, indices, **kwargs)
#    1358 return self
#
# File ~/Documents/api_model/env/lib/python3.10/site-packages/seaborn/axisgrid.py:1539, in PairGrid._map_bivariate(self, func, indices, **kwargs)
#    1537     if ax is None:  # i.e. we are in corner mode
#    1538         continue
# -> 1539     self._plot_bivariate(x_var, y_var, ax, func, **kws)
#    1540 self._add_axis_labels()
#    1542 if "hue" in signature(func).parameters:
#
# File ~/Documents/api_model/env/lib/python3.10/site-packages/seaborn/axisgrid.py:1579, in PairGrid._plot_bivariate(self, x_var, y_var, ax, func, **kwargs)
#    1577 kwargs.setdefault("hue_order", self._hue_order)
#    1578 kwargs.setdefault("palette", self._orig_palette)
# -> 1579 func(x=x, y=y, **kwargs)
#    1581 self._update_legend_data(ax)
#
# File ~/Documents/api_model/env/lib/python3.10/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~/Documents/api_model/env/lib/python3.10/site-packages/seaborn/distributions.py:1783, in kdeplot(x, y, shade, vertical, kernel, bw, gridsize, cut, clip, legend, cumulative, shade_lowest, cbar, cbar_ax, cbar_kws, ax, weights, hue, palette, hue_order, hue_norm, multiple, common_norm, common_grid, levels, thresh, bw_method, bw_adjust, log_scale, color, fill, data, data2, warn_singular, **kwargs)
#    1770     p.plot_univariate_density(
#    1771         multiple=multiple,
#    1772         common_norm=common_norm,
#    (...)
#    1778         **plot_kws,
#    1779     )
#    1781 else:
# -> 1783     p.plot_bivariate_density(
#    1784         common_norm=common_norm,
#    1785         fill=fill,
#    1786         levels=levels,
#    1787         thresh=thresh,
#    1788         legend=legend,
#    1789         color=color,
#    1790         warn_singular=warn_singular,
#    1791         cbar=cbar,
#    1792         cbar_ax=cbar_ax,
#    1793         cbar_kws=cbar_kws,
#    1794         estimate_kws=estimate_kws,
#    1795         **kwargs,
#    1796     )
#    1798 return ax
#
# File ~/Documents/api_model/env/lib/python3.10/site-packages/seaborn/distributions.py:1111, in _DistributionPlotter.plot_bivariate_density(self, common_norm, fill, levels, thresh, color, legend, cbar, warn_singular, cbar_ax, cbar_kws, estimate_kws, **contour_kws)
#    1109 # Estimate the density of observations at this level
#    1110 observations = observations["x"], observations["y"]
# -> 1111 density, support = estimator(*observations, weights=weights)
#    1113 # Transform the support grid back to the original scale
#    1114 xx, yy = support
#
# File ~/Documents/api_model/env/lib/python3.10/site-packages/seaborn/_statistics.py:189, in KDE.__call__(self, x1, x2, weights)
#     187     return self._eval_univariate(x1, weights)
#     188 else:
# --> 189     return self._eval_bivariate(x1, x2, weights)
#
# File ~/Documents/api_model/env/lib/python3.10/site-packages/seaborn/_statistics.py:180, in KDE._eval_bivariate(self, x1, x2, weights)
#     177 else:
#     179     xx1, xx2 = np.meshgrid(*support)
# --> 180     density = kde([xx1.ravel(), xx2.ravel()]).reshape(xx1.shape)
#     182 return density, support
#
# File ~/Documents/api_model/env/lib/python3.10/site-packages/scipy/stats/_kde.py:253, in gaussian_kde.evaluate(self, points)
#     250 else:
#     251     raise TypeError('%s has unexpected item size %d' %
#     252                     (output_dtype, itemsize))
# --> 253 result = gaussian_kernel_estimate[spec](self.dataset.T, self.weights[:, None],
#     254                                         points.T, self.inv_cov, output_dtype)
#     255 return result[:, 0]
#
# KeyboardInterrupt:

# %%
results.loc[:,col].corr()
# Out:
#                       HP    Attack   Defense   Sp. Atk   Sp. Def     Speed  \
# HP              1.000000  0.422386  0.239622  0.362380  0.378718  0.175952
# Attack          0.422386  1.000000  0.438687  0.396362  0.263990  0.381240
# Defense         0.239622  0.438687  1.000000  0.223549  0.510747  0.015227
# Sp. Atk         0.362380  0.396362  0.223549  1.000000  0.506121  0.473018
# Sp. Def         0.378718  0.263990  0.510747  0.506121  1.000000  0.259133
# Speed           0.175952  0.381240  0.015227  0.473018  0.259133  1.000000
# Win Percentage  0.258006  0.500181  0.129426  0.478940  0.324218  0.937742
#
#                 Win Percentage
# HP                    0.258006
# Attack                0.500181
# Defense               0.129426
# Sp. Atk               0.478940
# Sp. Def               0.324218
# Speed                 0.937742
# Win Percentage        1.000000

# %%
# https://datascience.stackexchange.com/questions/10459/calculation-and-visualization-of-correlation-matrix-with-pandas
# This function was taken from the link above 
def correlation_matrix(df):
    from matplotlib import pyplot as plt
    from matplotlib import cm as cm

    fig = plt.figure()
    ax1 = fig.add_subplot(111)
    cmap = cm.get_cmap('jet', 50)
    cax = ax1.imshow(df.corr(), interpolation="nearest", cmap=cmap)
    ax1.grid(True)
    plt.title('Pokemon Feature Correlation')
    labels=['Type 1','HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Win %']
    ax1.set_xticklabels(labels,fontsize=7)
    ax1.set_yticklabels(labels,fontsize=7)
    # Add colorbar, make sure to specify tick locations to match desired ticklabels
    fig.colorbar(cax, ticks=[0.00,.05,.10,.15,.20,.25,.30,.35,.40,.45,.50,.55,.60,.65,.70,.75,.8,.85,.90,.95,1])
    plt.show()

correlation_matrix(results.loc[:,col])
# Out:
# /tmp/ipykernel_9004/3231645601.py:14: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(labels,fontsize=7)
# /tmp/ipykernel_9004/3231645601.py:15: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_yticklabels(labels,fontsize=7)

# %%
sns.regplot(x="Speed", y="Win Percentage", data=results, logistic=True).set_title("Speed vs Win Percentage")
sns.lmplot(x="Speed", y="Win Percentage", data=results, hue = 'Type 1',  logistic=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /home/marmouset/Documents/api_model/notebooks/01-data-exploratory-analysis.ipynb Cellule 49 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/marmouset/Documents/api_model/notebooks/01-data-exploratory-analysis.ipynb#ch0000048?line=0'>1</a> sns.regplot(x="Speed", y="Win Percentage", data=results, logistic=True).set_title("Speed vs Win Percentage")
#       <a href='vscode-notebook-cell:/home/marmouset/Documents/api_model/notebooks/01-data-exploratory-analysis.ipynb#ch0000048?line=1'>2</a> sns.lmplot(x="Speed", y="Win Percentage", data=results, hue = 'Type 1',  logistic=True)
#
# File ~/Documents/api_model/env/lib/python3.10/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File ~/Documents/api_model/env/lib/python3.10/site-packages/seaborn/regression.py:863, in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     861 scatter_kws["marker"] = marker
#     862 line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 863 plotter.plot(ax, scatter_kws, line_kws)
#     864 return ax
#
# File ~/Documents/api_model/env/lib/python3.10/site-packages/seaborn/regression.py:370, in _RegressionPlotter.plot(self, ax, scatter_kws, line_kws)
#     367     self.scatterplot(ax, scatter_kws)
#     369 if self.fit_reg:
# --> 370     self.lineplot(ax, line_kws)
#     372 # Label the axes
#     373 if hasattr(self.x, "name"):
#
# File ~/Documents/api_model/env/lib/python3.10/site-packages/seaborn/regression.py:413, in _RegressionPlotter.lineplot(self, ax, kws)
#     411 """Draw the model."""
#     412 # Fit the regression model
# --> 413 grid, yhat, err_bands = self.fit_regression(ax)
#     414 edges = grid[0], grid[-1]
#     416 # Get set default aesthetics
#
# File ~/Documents/api_model/env/lib/python3.10/site-packages/seaborn/regression.py:208, in _RegressionPlotter.fit_regression(self, ax, x_range, grid)
#     206     yhat, yhat_boots = self.fit_poly(grid, self.order)
#     207 elif self.logistic:
# --> 208     from statsmodels.genmod.generalized_linear_model import GLM
#     209     from statsmodels.genmod.families import Binomial
#     210     yhat, yhat_boots = self.fit_statsmodels(grid, GLM,
#     211                                             family=Binomial())
#
# ModuleNotFoundError: No module named 'statsmodels'

# %%
ax = sns.regplot(x="Attack", y="Win Percentage", data=results).set_title("Attack vs Win Percentage")
sns.lmplot(x="Attack", y="Win Percentage", data=results, hue = 'Type 1',fit_reg =False)

# %% [markdown]
# ### Data cleaning

# %%
pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Number       800 non-null    int64
#  1   Name         800 non-null    object
#  2   Type 1       800 non-null    object
#  3   Type 2       414 non-null    object
#  4   HP           800 non-null    int64
#  5   Attack       800 non-null    int64
#  6   Defense      800 non-null    int64
#  7   Sp. Atk      800 non-null    int64
#  8   Sp. Def      800 non-null    int64
#  9   Speed        800 non-null    int64
#  10  Generation   800 non-null    int64
#  11  Legendary    800 non-null    bool
#  12  Total_stats  800 non-null    int64
# dtypes: bool(1), int64(9), object(3)
# memory usage: 114.3+ KB

# %%
combats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   First_pokemon   50000 non-null  int64
#  1   Second_pokemon  50000 non-null  int64
#  2   Winner          50000 non-null  int64
# dtypes: int64(3)
# memory usage: 1.1 MB

# %%
pokemon['Type 2'] = pokemon['Type 2'].fillna('None')

pokemon['Legendary'] = pokemon['Legendary'].map({False: 0, True:1})

# %%
pokemon
# Out:
#      Number            Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0         1       Bulbasaur    Grass  Poison  45      49       49       65
# 1         2         Ivysaur    Grass  Poison  60      62       63       80
# 2         3        Venusaur    Grass  Poison  80      82       83      100
# 3         4   Mega Venusaur    Grass  Poison  80     100      123      122
# 4         5      Charmander     Fire    None  39      52       43       60
# ..      ...             ...      ...     ...  ..     ...      ...      ...
# 795     796         Diancie     Rock   Fairy  50     100      150      100
# 796     797    Mega Diancie     Rock   Fairy  50     160      110      160
# 797     798  Hoopa Confined  Psychic   Ghost  80     110       60      150
# 798     799   Hoopa Unbound  Psychic    Dark  80     160       60      170
# 799     800       Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary  Total_stats
# 0         65     45           1          0          318
# 1         80     60           1          0          405
# 2        100     80           1          0          525
# 3        120     80           1          0          625
# 4         50     65           1          0          309
# ..       ...    ...         ...        ...          ...
# 795      150     50           6          1          600
# 796      110    110           6          1          700
# 797      130     70           6          1          600
# 798      130     80           6          1          680
# 799       90     70           6          1          600
#
# [800 rows x 13 columns]

# %%
name_df = pokemon.iloc[:, 0:2]
name_dict = name_df.set_index('Number').to_dict()['Name']
name_dict
# Out:
# {1: 'Bulbasaur',
#  2: 'Ivysaur',
#  3: 'Venusaur',
#  4: 'Mega Venusaur',
#  5: 'Charmander',
#  6: 'Charmeleon',
#  7: 'Charizard',
#  8: 'Mega Charizard X',
#  9: 'Mega Charizard Y',
#  10: 'Squirtle',
#  11: 'Wartortle',
#  12: 'Blastoise',
#  13: 'Mega Blastoise',
#  14: 'Caterpie',
#  15: 'Metapod',
#  16: 'Butterfree',
#  17: 'Weedle',
#  18: 'Kakuna',
#  19: 'Beedrill',
#  20: 'Mega Beedrill',
#  21: 'Pidgey',
#  22: 'Pidgeotto',
#  23: 'Pidgeot',
#  24: 'Mega Pidgeot',
#  25: 'Rattata',
#  26: 'Raticate',
#  27: 'Spearow',
#  28: 'Fearow',
#  29: 'Ekans',
#  30: 'Arbok',
#  31: 'Pikachu',
#  32: 'Raichu',
#  33: 'Sandshrew',
#  34: 'Sandslash',
#  35: 'Nidoran♀',
#  36: 'Nidorina',
#  37: 'Nidoqueen',
#  38: 'Nidoran♂',
#  39: 'Nidorino',
#  40: 'Nidoking',
#  41: 'Clefairy',
#  42: 'Clefable',
#  43: 'Vulpix',
#  44: 'Ninetales',
#  45: 'Jigglypuff',
#  46: 'Wigglytuff',
#  47: 'Zubat',
#  48: 'Golbat',
#  49: 'Oddish',
#  50: 'Gloom',
#  51: 'Vileplume',
#  52: 'Paras',
#  53: 'Parasect',
#  54: 'Venonat',
#  55: 'Venomoth',
#  56: 'Diglett',
#  57: 'Dugtrio',
#  58: 'Meowth',
#  59: 'Persian',
#  60: 'Psyduck',
#  61: 'Golduck',
#  62: 'Mankey',
#  63: 'Primeape',
#  64: 'Growlithe',
#  65: 'Arcanine',
#  66: 'Poliwag',
#  67: 'Poliwhirl',
#  68: 'Poliwrath',
#  69: 'Abra',
#  70: 'Kadabra',
#  71: 'Alakazam',
#  72: 'Mega Alakazam',
#  73: 'Machop',
#  74: 'Machoke',
#  75: 'Machamp',
#  76: 'Bellsprout',
#  77: 'Weepinbell',
#  78: 'Victreebel',
#  79: 'Tentacool',
#  80: 'Tentacruel',
#  81: 'Geodude',
#  82: 'Graveler',
#  83: 'Golem',
#  84: 'Ponyta',
#  85: 'Rapidash',
#  86: 'Slowpoke',
#  87: 'Slowbro',
#  88: 'Mega Slowbro',
#  89: 'Magnemite',
#  90: 'Magneton',
#  91: "Farfetch'd",
#  92: 'Doduo',
#  93: 'Dodrio',
#  94: 'Seel',
#  95: 'Dewgong',
#  96: 'Grimer',
#  97: 'Muk',
#  98: 'Shellder',
#  99: 'Cloyster',
#  100: 'Gastly',
#  101: 'Haunter',
#  102: 'Gengar',
#  103: 'Mega Gengar',
#  104: 'Onix',
#  105: 'Drowzee',
#  106: 'Hypno',
#  107: 'Krabby',
#  108: 'Kingler',
#  109: 'Voltorb',
#  110: 'Electrode',
#  111: 'Exeggcute',
#  112: 'Exeggutor',
#  113: 'Cubone',
#  114: 'Marowak',
#  115: 'Hitmonlee',
#  116: 'Hitmonchan',
#  117: 'Lickitung',
#  118: 'Koffing',
#  119: 'Weezing',
#  120: 'Rhyhorn',
#  121: 'Rhydon',
#  122: 'Chansey',
#  123: 'Tangela',
#  124: 'Kangaskhan',
#  125: 'Mega Kangaskhan',
#  126: 'Horsea',
#  127: 'Seadra',
#  128: 'Goldeen',
#  129: 'Seaking',
#  130: 'Staryu',
#  131: 'Starmie',
#  132: 'Mr. Mime',
#  133: 'Scyther',
#  134: 'Jynx',
#  135: 'Electabuzz',
#  136: 'Magmar',
#  137: 'Pinsir',
#  138: 'Mega Pinsir',
#  139: 'Tauros',
#  140: 'Magikarp',
#  141: 'Gyarados',
#  142: 'Mega Gyarados',
#  143: 'Lapras',
#  144: 'Ditto',
#  145: 'Eevee',
#  146: 'Vaporeon',
#  147: 'Jolteon',
#  148: 'Flareon',
#  149: 'Porygon',
#  150: 'Omanyte',
#  151: 'Omastar',
#  152: 'Kabuto',
#  153: 'Kabutops',
#  154: 'Aerodactyl',
#  155: 'Mega Aerodactyl',
#  156: 'Snorlax',
#  157: 'Articuno',
#  158: 'Zapdos',
#  159: 'Moltres',
#  160: 'Dratini',
#  161: 'Dragonair',
#  162: 'Dragonite',
#  163: 'Mewtwo',
#  164: 'Mega Mewtwo X',
#  165: 'Mega Mewtwo Y',
#  166: 'Mew',
#  167: 'Chikorita',
#  168: 'Bayleef',
#  169: 'Meganium',
#  170: 'Cyndaquil',
#  171: 'Quilava',
#  172: 'Typhlosion',
#  173: 'Totodile',
#  174: 'Croconaw',
#  175: 'Feraligatr',
#  176: 'Sentret',
#  177: 'Furret',
#  178: 'Hoothoot',
#  179: 'Noctowl',
#  180: 'Ledyba',
#  181: 'Ledian',
#  182: 'Spinarak',
#  183: 'Ariados',
#  184: 'Crobat',
#  185: 'Chinchou',
#  186: 'Lanturn',
#  187: 'Pichu',
#  188: 'Cleffa',
#  189: 'Igglybuff',
#  190: 'Togepi',
#  191: 'Togetic',
#  192: 'Natu',
#  193: 'Xatu',
#  194: 'Mareep',
#  195: 'Flaaffy',
#  196: 'Ampharos',
#  197: 'Mega Ampharos',
#  198: 'Bellossom',
#  199: 'Marill',
#  200: 'Azumarill',
#  201: 'Sudowoodo',
#  202: 'Politoed',
#  203: 'Hoppip',
#  204: 'Skiploom',
#  205: 'Jumpluff',
#  206: 'Aipom',
#  207: 'Sunkern',
#  208: 'Sunflora',
#  209: 'Yanma',
#  210: 'Wooper',
#  211: 'Quagsire',
#  212: 'Espeon',
#  213: 'Umbreon',
#  214: 'Murkrow',
#  215: 'Slowking',
#  216: 'Misdreavus',
#  217: 'Unown',
#  218: 'Wobbuffet',
#  219: 'Girafarig',
#  220: 'Pineco',
#  221: 'Forretress',
#  222: 'Dunsparce',
#  223: 'Gligar',
#  224: 'Steelix',
#  225: 'Mega Steelix',
#  226: 'Snubbull',
#  227: 'Granbull',
#  228: 'Qwilfish',
#  229: 'Scizor',
#  230: 'Mega Scizor',
#  231: 'Shuckle',
#  232: 'Heracross',
#  233: 'Mega Heracross',
#  234: 'Sneasel',
#  235: 'Teddiursa',
#  236: 'Ursaring',
#  237: 'Slugma',
#  238: 'Magcargo',
#  239: 'Swinub',
#  240: 'Piloswine',
#  241: 'Corsola',
#  242: 'Remoraid',
#  243: 'Octillery',
#  244: 'Delibird',
#  245: 'Mantine',
#  246: 'Skarmory',
#  247: 'Houndour',
#  248: 'Houndoom',
#  249: 'Mega Houndoom',
#  250: 'Kingdra',
#  251: 'Phanpy',
#  252: 'Donphan',
#  253: 'Porygon2',
#  254: 'Stantler',
#  255: 'Smeargle',
#  256: 'Tyrogue',
#  257: 'Hitmontop',
#  258: 'Smoochum',
#  259: 'Elekid',
#  260: 'Magby',
#  261: 'Miltank',
#  262: 'Blissey',
#  263: 'Raikou',
#  264: 'Entei',
#  265: 'Suicune',
#  266: 'Larvitar',
#  267: 'Pupitar',
#  268: 'Tyranitar',
#  269: 'Mega Tyranitar',
#  270: 'Lugia',
#  271: 'Ho-oh',
#  272: 'Celebi',
#  273: 'Treecko',
#  274: 'Grovyle',
#  275: 'Sceptile',
#  276: 'Mega Sceptile',
#  277: 'Torchic',
#  278: 'Combusken',
#  279: 'Blaziken',
#  280: 'Mega Blaziken',
#  281: 'Mudkip',
#  282: 'Marshtomp',
#  283: 'Swampert',
#  284: 'Mega Swampert',
#  285: 'Poochyena',
#  286: 'Mightyena',
#  287: 'Zigzagoon',
#  288: 'Linoone',
#  289: 'Wurmple',
#  290: 'Silcoon',
#  291: 'Beautifly',
#  292: 'Cascoon',
#  293: 'Dustox',
#  294: 'Lotad',
#  295: 'Lombre',
#  296: 'Ludicolo',
#  297: 'Seedot',
#  298: 'Nuzleaf',
#  299: 'Shiftry',
#  300: 'Taillow',
#  301: 'Swellow',
#  302: 'Wingull',
#  303: 'Pelipper',
#  304: 'Ralts',
#  305: 'Kirlia',
#  306: 'Gardevoir',
#  307: 'Mega Gardevoir',
#  308: 'Surskit',
#  309: 'Masquerain',
#  310: 'Shroomish',
#  311: 'Breloom',
#  312: 'Slakoth',
#  313: 'Vigoroth',
#  314: 'Slaking',
#  315: 'Nincada',
#  316: 'Ninjask',
#  317: 'Shedinja',
#  318: 'Whismur',
#  319: 'Loudred',
#  320: 'Exploud',
#  321: 'Makuhita',
#  322: 'Hariyama',
#  323: 'Azurill',
#  324: 'Nosepass',
#  325: 'Skitty',
#  326: 'Delcatty',
#  327: 'Sableye',
#  328: 'Mega Sableye',
#  329: 'Mawile',
#  330: 'Mega Mawile',
#  331: 'Aron',
#  332: 'Lairon',
#  333: 'Aggron',
#  334: 'Mega Aggron',
#  335: 'Meditite',
#  336: 'Medicham',
#  337: 'Mega Medicham',
#  338: 'Electrike',
#  339: 'Manectric',
#  340: 'Mega Manectric',
#  341: 'Plusle',
#  342: 'Minun',
#  343: 'Volbeat',
#  344: 'Illumise',
#  345: 'Roselia',
#  346: 'Gulpin',
#  347: 'Swalot',
#  348: 'Carvanha',
#  349: 'Sharpedo',
#  350: 'Mega Sharpedo',
#  351: 'Wailmer',
#  352: 'Wailord',
#  353: 'Numel',
#  354: 'Camerupt',
#  355: 'Mega Camerupt',
#  356: 'Torkoal',
#  357: 'Spoink',
#  358: 'Grumpig',
#  359: 'Spinda',
#  360: 'Trapinch',
#  361: 'Vibrava',
#  362: 'Flygon',
#  363: 'Cacnea',
#  364: 'Cacturne',
#  365: 'Swablu',
#  366: 'Altaria',
#  367: 'Mega Altaria',
#  368: 'Zangoose',
#  369: 'Seviper',
#  370: 'Lunatone',
#  371: 'Solrock',
#  372: 'Barboach',
#  373: 'Whiscash',
#  374: 'Corphish',
#  375: 'Crawdaunt',
#  376: 'Baltoy',
#  377: 'Claydol',
#  378: 'Lileep',
#  379: 'Cradily',
#  380: 'Anorith',
#  381: 'Armaldo',
#  382: 'Feebas',
#  383: 'Milotic',
#  384: 'Castform',
#  385: 'Kecleon',
#  386: 'Shuppet',
#  387: 'Banette',
#  388: 'Mega Banette',
#  389: 'Duskull',
#  390: 'Dusclops',
#  391: 'Tropius',
#  392: 'Chimecho',
#  393: 'Absol',
#  394: 'Mega Absol',
#  395: 'Wynaut',
#  396: 'Snorunt',
#  397: 'Glalie',
#  398: 'Mega Glalie',
#  399: 'Spheal',
#  400: 'Sealeo',
#  401: 'Walrein',
#  402: 'Clamperl',
#  403: 'Huntail',
#  404: 'Gorebyss',
#  405: 'Relicanth',
#  406: 'Luvdisc',
#  407: 'Bagon',
#  408: 'Shelgon',
#  409: 'Salamence',
#  410: 'Mega Salamence',
#  411: 'Beldum',
#  412: 'Metang',
#  413: 'Metagross',
#  414: 'Mega Metagross',
#  415: 'Regirock',
#  416: 'Regice',
#  417: 'Registeel',
#  418: 'Latias',
#  419: 'Mega Latias',
#  420: 'Latios',
#  421: 'Mega Latios',
#  422: 'Kyogre',
#  423: 'Primal Kyogre',
#  424: 'Groudon',
#  425: 'Primal Groudon',
#  426: 'Rayquaza',
#  427: 'Mega Rayquaza',
#  428: 'Jirachi',
#  429: 'Deoxys Normal Forme',
#  430: 'DeoxysAttack Forme',
#  431: 'Deoxys Defense Forme',
#  432: 'Deoxys Speed Forme',
#  433: 'Turtwig',
#  434: 'Grotle',
#  435: 'Torterra',
#  436: 'Chimchar',
#  437: 'Monferno',
#  438: 'Infernape',
#  439: 'Piplup',
#  440: 'Prinplup',
#  441: 'Empoleon',
#  442: 'Starly',
#  443: 'Staravia',
#  444: 'Staraptor',
#  445: 'Bidoof',
#  446: 'Bibarel',
#  447: 'Kricketot',
#  448: 'Kricketune',
#  449: 'Shinx',
#  450: 'Luxio',
#  451: 'Luxray',
#  452: 'Budew',
#  453: 'Roserade',
#  454: 'Cranidos',
#  455: 'Rampardos',
#  456: 'Shieldon',
#  457: 'Bastiodon',
#  458: 'Burmy',
#  459: 'Wormadam Plant Cloak',
#  460: 'Wormadam Sandy Cloak',
#  461: 'Wormadam Trash Cloak',
#  462: 'Mothim',
#  463: 'Combee',
#  464: 'Vespiquen',
#  465: 'Pachirisu',
#  466: 'Buizel',
#  467: 'Floatzel',
#  468: 'Cherubi',
#  469: 'Cherrim',
#  470: 'Shellos',
#  471: 'Gastrodon',
#  472: 'Ambipom',
#  473: 'Drifloon',
#  474: 'Drifblim',
#  475: 'Buneary',
#  476: 'Lopunny',
#  477: 'Mega Lopunny',
#  478: 'Mismagius',
#  479: 'Honchkrow',
#  480: 'Glameow',
#  481: 'Purugly',
#  482: 'Chingling',
#  483: 'Stunky',
#  484: 'Skuntank',
#  485: 'Bronzor',
#  486: 'Bronzong',
#  487: 'Bonsly',
#  488: 'Mime Jr.',
#  489: 'Happiny',
#  490: 'Chatot',
#  491: 'Spiritomb',
#  492: 'Gible',
#  493: 'Gabite',
#  494: 'Garchomp',
#  495: 'Mega Garchomp',
#  496: 'Munchlax',
#  497: 'Riolu',
#  498: 'Lucario',
#  499: 'Mega Lucario',
#  500: 'Hippopotas',
#  501: 'Hippowdon',
#  502: 'Skorupi',
#  503: 'Drapion',
#  504: 'Croagunk',
#  505: 'Toxicroak',
#  506: 'Carnivine',
#  507: 'Finneon',
#  508: 'Lumineon',
#  509: 'Mantyke',
#  510: 'Snover',
#  511: 'Abomasnow',
#  512: 'Mega Abomasnow',
#  513: 'Weavile',
#  514: 'Magnezone',
#  515: 'Lickilicky',
#  516: 'Rhyperior',
#  517: 'Tangrowth',
#  518: 'Electivire',
#  519: 'Magmortar',
#  520: 'Togekiss',
#  521: 'Yanmega',
#  522: 'Leafeon',
#  523: 'Glaceon',
#  524: 'Gliscor',
#  525: 'Mamoswine',
#  526: 'Porygon-Z',
#  527: 'Gallade',
#  528: 'Mega Gallade',
#  529: 'Probopass',
#  530: 'Dusknoir',
#  531: 'Froslass',
#  532: 'Rotom',
#  533: 'Heat Rotom',
#  534: 'Wash Rotom',
#  535: 'Frost Rotom',
#  536: 'Fan Rotom',
#  537: 'Mow Rotom',
#  538: 'Uxie',
#  539: 'Mesprit',
#  540: 'Azelf',
#  541: 'Dialga',
#  542: 'Palkia',
#  543: 'Heatran',
#  544: 'Regigigas',
#  545: 'Giratina Altered Forme',
#  546: 'Giratina Origin Forme',
#  547: 'Cresselia',
#  548: 'Phione',
#  549: 'Manaphy',
#  550: 'Darkrai',
#  551: 'Shaymin Land Forme',
#  552: 'Shaymin Sky Forme',
#  553: 'Arceus',
#  554: 'Victini',
#  555: 'Snivy',
#  556: 'Servine',
#  557: 'Serperior',
#  558: 'Tepig',
#  559: 'Pignite',
#  560: 'Emboar',
#  561: 'Oshawott',
#  562: 'Dewott',
#  563: 'Samurott',
#  564: 'Patrat',
#  565: 'Watchog',
#  566: 'Lillipup',
#  567: 'Herdier',
#  568: 'Stoutland',
#  569: 'Purrloin',
#  570: 'Liepard',
#  571: 'Pansage',
#  572: 'Simisage',
#  573: 'Pansear',
#  574: 'Simisear',
#  575: 'Panpour',
#  576: 'Simipour',
#  577: 'Munna',
#  578: 'Musharna',
#  579: 'Pidove',
#  580: 'Tranquill',
#  581: 'Unfezant',
#  582: 'Blitzle',
#  583: 'Zebstrika',
#  584: 'Roggenrola',
#  585: 'Boldore',
#  586: 'Gigalith',
#  587: 'Woobat',
#  588: 'Swoobat',
#  589: 'Drilbur',
#  590: 'Excadrill',
#  591: 'Audino',
#  592: 'Mega Audino',
#  593: 'Timburr',
#  594: 'Gurdurr',
#  595: 'Conkeldurr',
#  596: 'Tympole',
#  597: 'Palpitoad',
#  598: 'Seismitoad',
#  599: 'Throh',
#  600: 'Sawk',
#  601: 'Sewaddle',
#  602: 'Swadloon',
#  603: 'Leavanny',
#  604: 'Venipede',
#  605: 'Whirlipede',
#  606: 'Scolipede',
#  607: 'Cottonee',
#  608: 'Whimsicott',
#  609: 'Petilil',
#  610: 'Lilligant',
#  611: 'Basculin',
#  612: 'Sandile',
#  613: 'Krokorok',
#  614: 'Krookodile',
#  615: 'Darumaka',
#  616: 'Darmanitan Standard Mode',
#  617: 'Darmanitan Zen Mode',
#  618: 'Maractus',
#  619: 'Dwebble',
#  620: 'Crustle',
#  621: 'Scraggy',
#  622: 'Scrafty',
#  623: 'Sigilyph',
#  624: 'Yamask',
#  625: 'Cofagrigus',
#  626: 'Tirtouga',
#  627: 'Carracosta',
#  628: 'Archen',
#  629: 'Archeops',
#  630: 'Trubbish',
#  631: 'Garbodor',
#  632: 'Zorua',
#  633: 'Zoroark',
#  634: 'Minccino',
#  635: 'Cinccino',
#  636: 'Gothita',
#  637: 'Gothorita',
#  638: 'Gothitelle',
#  639: 'Solosis',
#  640: 'Duosion',
#  641: 'Reuniclus',
#  642: 'Ducklett',
#  643: 'Swanna',
#  644: 'Vanillite',
#  645: 'Vanillish',
#  646: 'Vanilluxe',
#  647: 'Deerling',
#  648: 'Sawsbuck',
#  649: 'Emolga',
#  650: 'Karrablast',
#  651: 'Escavalier',
#  652: 'Foongus',
#  653: 'Amoonguss',
#  654: 'Frillish',
#  655: 'Jellicent',
#  656: 'Alomomola',
#  657: 'Joltik',
#  658: 'Galvantula',
#  659: 'Ferroseed',
#  660: 'Ferrothorn',
#  661: 'Klink',
#  662: 'Klang',
#  663: 'Klinklang',
#  664: 'Tynamo',
#  665: 'Eelektrik',
#  666: 'Eelektross',
#  667: 'Elgyem',
#  668: 'Beheeyem',
#  669: 'Litwick',
#  670: 'Lampent',
#  671: 'Chandelure',
#  672: 'Axew',
#  673: 'Fraxure',
#  674: 'Haxorus',
#  675: 'Cubchoo',
#  676: 'Beartic',
#  677: 'Cryogonal',
#  678: 'Shelmet',
#  679: 'Accelgor',
#  680: 'Stunfisk',
#  681: 'Mienfoo',
#  682: 'Mienshao',
#  683: 'Druddigon',
#  684: 'Golett',
#  685: 'Golurk',
#  686: 'Pawniard',
#  687: 'Bisharp',
#  688: 'Bouffalant',
#  689: 'Rufflet',
#  690: 'Braviary',
#  691: 'Vullaby',
#  692: 'Mandibuzz',
#  693: 'Heatmor',
#  694: 'Durant',
#  695: 'Deino',
#  696: 'Zweilous',
#  697: 'Hydreigon',
#  698: 'Larvesta',
#  699: 'Volcarona',
#  700: 'Cobalion',
#  701: 'Terrakion',
#  702: 'Virizion',
#  703: 'Tornadus Incarnate Forme',
#  704: 'Tornadus Therian Forme',
#  705: 'Thundurus Incarnate Forme',
#  706: 'Thundurus Therian Forme',
#  707: 'Reshiram',
#  708: 'Zekrom',
#  709: 'Landorus Incarnate Forme',
#  710: 'Landorus Therian Forme',
#  711: 'Kyurem',
#  712: 'Kyurem Black Kyurem',
#  713: 'Kyurem White Kyurem',
#  714: 'Keldeo Ordinary Forme',
#  715: 'Keldeo Resolute Forme',
#  716: 'Meloetta Aria Forme',
#  717: 'Meloetta Pirouette Forme',
#  718: 'Genesect',
#  719: 'Chespin',
#  720: 'Quilladin',
#  721: 'Chesnaught',
#  722: 'Fennekin',
#  723: 'Braixen',
#  724: 'Delphox',
#  725: 'Froakie',
#  726: 'Frogadier',
#  727: 'Greninja',
#  728: 'Bunnelby',
#  729: 'Diggersby',
#  730: 'Fletchling',
#  731: 'Fletchinder',
#  732: 'Talonflame',
#  733: 'Scatterbug',
#  734: 'Spewpa',
#  735: 'Vivillon',
#  736: 'Litleo',
#  737: 'Pyroar',
#  738: 'Flabébé',
#  739: 'Floette',
#  740: 'Florges',
#  741: 'Skiddo',
#  742: 'Gogoat',
#  743: 'Pancham',
#  744: 'Pangoro',
#  745: 'Furfrou',
#  746: 'Espurr',
#  747: 'Meowstic Male',
#  748: 'Meowstic Female',
#  749: 'Honedge',
#  750: 'Doublade',
#  751: 'Aegislash Blade Forme',
#  752: 'Aegislash Shield Forme',
#  753: 'Spritzee',
#  754: 'Aromatisse',
#  755: 'Swirlix',
#  756: 'Slurpuff',
#  757: 'Inkay',
#  758: 'Malamar',
#  759: 'Binacle',
#  760: 'Barbaracle',
#  761: 'Skrelp',
#  762: 'Dragalge',
#  763: 'Clauncher',
#  764: 'Clawitzer',
#  765: 'Helioptile',
#  766: 'Heliolisk',
#  767: 'Tyrunt',
#  768: 'Tyrantrum',
#  769: 'Amaura',
#  770: 'Aurorus',
#  771: 'Sylveon',
#  772: 'Hawlucha',
#  773: 'Dedenne',
#  774: 'Carbink',
#  775: 'Goomy',
#  776: 'Sliggoo',
#  777: 'Goodra',
#  778: 'Klefki',
#  779: 'Phantump',
#  780: 'Trevenant',
#  781: 'Pumpkaboo Average Size',
#  782: 'Pumpkaboo Small Size',
#  783: 'Pumpkaboo Large Size',
#  784: 'Pumpkaboo Super Size',
#  785: 'Gourgeist Average Size',
#  786: 'Gourgeist Small Size',
#  787: 'Gourgeist Large Size',
#  788: 'Gourgeist Super Size',
#  789: 'Bergmite',
#  790: 'Avalugg',
#  791: 'Noibat',
#  792: 'Noivern',
#  793: 'Xerneas',
#  794: 'Yveltal',
#  795: 'Zygarde Half Forme',
#  796: 'Diancie',
#  797: 'Mega Diancie',
#  798: 'Hoopa Confined',
#  799: 'Hoopa Unbound',
#  800: 'Volcanion'}

# %%
#creating dictionaries
type_df = pokemon.iloc[:, 0:4]
type_df = type_df.drop('Name', axis=1)

type_dict = type_df.set_index('Number').T.to_dict('list')
type_dict
# Out:
# {1: ['Grass', 'Poison'],
#  2: ['Grass', 'Poison'],
#  3: ['Grass', 'Poison'],
#  4: ['Grass', 'Poison'],
#  5: ['Fire', 'None'],
#  6: ['Fire', 'None'],
#  7: ['Fire', 'Flying'],
#  8: ['Fire', 'Dragon'],
#  9: ['Fire', 'Flying'],
#  10: ['Water', 'None'],
#  11: ['Water', 'None'],
#  12: ['Water', 'None'],
#  13: ['Water', 'None'],
#  14: ['Bug', 'None'],
#  15: ['Bug', 'None'],
#  16: ['Bug', 'Flying'],
#  17: ['Bug', 'Poison'],
#  18: ['Bug', 'Poison'],
#  19: ['Bug', 'Poison'],
#  20: ['Bug', 'Poison'],
#  21: ['Normal', 'Flying'],
#  22: ['Normal', 'Flying'],
#  23: ['Normal', 'Flying'],
#  24: ['Normal', 'Flying'],
#  25: ['Normal', 'None'],
#  26: ['Normal', 'None'],
#  27: ['Normal', 'Flying'],
#  28: ['Normal', 'Flying'],
#  29: ['Poison', 'None'],
#  30: ['Poison', 'None'],
#  31: ['Electric', 'None'],
#  32: ['Electric', 'None'],
#  33: ['Ground', 'None'],
#  34: ['Ground', 'None'],
#  35: ['Poison', 'None'],
#  36: ['Poison', 'None'],
#  37: ['Poison', 'Ground'],
#  38: ['Poison', 'None'],
#  39: ['Poison', 'None'],
#  40: ['Poison', 'Ground'],
#  41: ['Fairy', 'None'],
#  42: ['Fairy', 'None'],
#  43: ['Fire', 'None'],
#  44: ['Fire', 'None'],
#  45: ['Normal', 'Fairy'],
#  46: ['Normal', 'Fairy'],
#  47: ['Poison', 'Flying'],
#  48: ['Poison', 'Flying'],
#  49: ['Grass', 'Poison'],
#  50: ['Grass', 'Poison'],
#  51: ['Grass', 'Poison'],
#  52: ['Bug', 'Grass'],
#  53: ['Bug', 'Grass'],
#  54: ['Bug', 'Poison'],
#  55: ['Bug', 'Poison'],
#  56: ['Ground', 'None'],
#  57: ['Ground', 'None'],
#  58: ['Normal', 'None'],
#  59: ['Normal', 'None'],
#  60: ['Water', 'None'],
#  61: ['Water', 'None'],
#  62: ['Fighting', 'None'],
#  63: ['Fighting', 'None'],
#  64: ['Fire', 'None'],
#  65: ['Fire', 'None'],
#  66: ['Water', 'None'],
#  67: ['Water', 'None'],
#  68: ['Water', 'Fighting'],
#  69: ['Psychic', 'None'],
#  70: ['Psychic', 'None'],
#  71: ['Psychic', 'None'],
#  72: ['Psychic', 'None'],
#  73: ['Fighting', 'None'],
#  74: ['Fighting', 'None'],
#  75: ['Fighting', 'None'],
#  76: ['Grass', 'Poison'],
#  77: ['Grass', 'Poison'],
#  78: ['Grass', 'Poison'],
#  79: ['Water', 'Poison'],
#  80: ['Water', 'Poison'],
#  81: ['Rock', 'Ground'],
#  82: ['Rock', 'Ground'],
#  83: ['Rock', 'Ground'],
#  84: ['Fire', 'None'],
#  85: ['Fire', 'None'],
#  86: ['Water', 'Psychic'],
#  87: ['Water', 'Psychic'],
#  88: ['Water', 'Psychic'],
#  89: ['Electric', 'Steel'],
#  90: ['Electric', 'Steel'],
#  91: ['Normal', 'Flying'],
#  92: ['Normal', 'Flying'],
#  93: ['Normal', 'Flying'],
#  94: ['Water', 'None'],
#  95: ['Water', 'Ice'],
#  96: ['Poison', 'None'],
#  97: ['Poison', 'None'],
#  98: ['Water', 'None'],
#  99: ['Water', 'Ice'],
#  100: ['Ghost', 'Poison'],
#  101: ['Ghost', 'Poison'],
#  102: ['Ghost', 'Poison'],
#  103: ['Ghost', 'Poison'],
#  104: ['Rock', 'Ground'],
#  105: ['Psychic', 'None'],
#  106: ['Psychic', 'None'],
#  107: ['Water', 'None'],
#  108: ['Water', 'None'],
#  109: ['Electric', 'None'],
#  110: ['Electric', 'None'],
#  111: ['Grass', 'Psychic'],
#  112: ['Grass', 'Psychic'],
#  113: ['Ground', 'None'],
#  114: ['Ground', 'None'],
#  115: ['Fighting', 'None'],
#  116: ['Fighting', 'None'],
#  117: ['Normal', 'None'],
#  118: ['Poison', 'None'],
#  119: ['Poison', 'None'],
#  120: ['Ground', 'Rock'],
#  121: ['Ground', 'Rock'],
#  122: ['Normal', 'None'],
#  123: ['Grass', 'None'],
#  124: ['Normal', 'None'],
#  125: ['Normal', 'None'],
#  126: ['Water', 'None'],
#  127: ['Water', 'None'],
#  128: ['Water', 'None'],
#  129: ['Water', 'None'],
#  130: ['Water', 'None'],
#  131: ['Water', 'Psychic'],
#  132: ['Psychic', 'Fairy'],
#  133: ['Bug', 'Flying'],
#  134: ['Ice', 'Psychic'],
#  135: ['Electric', 'None'],
#  136: ['Fire', 'None'],
#  137: ['Bug', 'None'],
#  138: ['Bug', 'Flying'],
#  139: ['Normal', 'None'],
#  140: ['Water', 'None'],
#  141: ['Water', 'Flying'],
#  142: ['Water', 'Dark'],
#  143: ['Water', 'Ice'],
#  144: ['Normal', 'None'],
#  145: ['Normal', 'None'],
#  146: ['Water', 'None'],
#  147: ['Electric', 'None'],
#  148: ['Fire', 'None'],
#  149: ['Normal', 'None'],
#  150: ['Rock', 'Water'],
#  151: ['Rock', 'Water'],
#  152: ['Rock', 'Water'],
#  153: ['Rock', 'Water'],
#  154: ['Rock', 'Flying'],
#  155: ['Rock', 'Flying'],
#  156: ['Normal', 'None'],
#  157: ['Ice', 'Flying'],
#  158: ['Electric', 'Flying'],
#  159: ['Fire', 'Flying'],
#  160: ['Dragon', 'None'],
#  161: ['Dragon', 'None'],
#  162: ['Dragon', 'Flying'],
#  163: ['Psychic', 'None'],
#  164: ['Psychic', 'Fighting'],
#  165: ['Psychic', 'None'],
#  166: ['Psychic', 'None'],
#  167: ['Grass', 'None'],
#  168: ['Grass', 'None'],
#  169: ['Grass', 'None'],
#  170: ['Fire', 'None'],
#  171: ['Fire', 'None'],
#  172: ['Fire', 'None'],
#  173: ['Water', 'None'],
#  174: ['Water', 'None'],
#  175: ['Water', 'None'],
#  176: ['Normal', 'None'],
#  177: ['Normal', 'None'],
#  178: ['Normal', 'Flying'],
#  179: ['Normal', 'Flying'],
#  180: ['Bug', 'Flying'],
#  181: ['Bug', 'Flying'],
#  182: ['Bug', 'Poison'],
#  183: ['Bug', 'Poison'],
#  184: ['Poison', 'Flying'],
#  185: ['Water', 'Electric'],
#  186: ['Water', 'Electric'],
#  187: ['Electric', 'None'],
#  188: ['Fairy', 'None'],
#  189: ['Normal', 'Fairy'],
#  190: ['Fairy', 'None'],
#  191: ['Fairy', 'Flying'],
#  192: ['Psychic', 'Flying'],
#  193: ['Psychic', 'Flying'],
#  194: ['Electric', 'None'],
#  195: ['Electric', 'None'],
#  196: ['Electric', 'None'],
#  197: ['Electric', 'Dragon'],
#  198: ['Grass', 'None'],
#  199: ['Water', 'Fairy'],
#  200: ['Water', 'Fairy'],
#  201: ['Rock', 'None'],
#  202: ['Water', 'None'],
#  203: ['Grass', 'Flying'],
#  204: ['Grass', 'Flying'],
#  205: ['Grass', 'Flying'],
#  206: ['Normal', 'None'],
#  207: ['Grass', 'None'],
#  208: ['Grass', 'None'],
#  209: ['Bug', 'Flying'],
#  210: ['Water', 'Ground'],
#  211: ['Water', 'Ground'],
#  212: ['Psychic', 'None'],
#  213: ['Dark', 'None'],
#  214: ['Dark', 'Flying'],
#  215: ['Water', 'Psychic'],
#  216: ['Ghost', 'None'],
#  217: ['Psychic', 'None'],
#  218: ['Psychic', 'None'],
#  219: ['Normal', 'Psychic'],
#  220: ['Bug', 'None'],
#  221: ['Bug', 'Steel'],
#  222: ['Normal', 'None'],
#  223: ['Ground', 'Flying'],
#  224: ['Steel', 'Ground'],
#  225: ['Steel', 'Ground'],
#  226: ['Fairy', 'None'],
#  227: ['Fairy', 'None'],
#  228: ['Water', 'Poison'],
#  229: ['Bug', 'Steel'],
#  230: ['Bug', 'Steel'],
#  231: ['Bug', 'Rock'],
#  232: ['Bug', 'Fighting'],
#  233: ['Bug', 'Fighting'],
#  234: ['Dark', 'Ice'],
#  235: ['Normal', 'None'],
#  236: ['Normal', 'None'],
#  237: ['Fire', 'None'],
#  238: ['Fire', 'Rock'],
#  239: ['Ice', 'Ground'],
#  240: ['Ice', 'Ground'],
#  241: ['Water', 'Rock'],
#  242: ['Water', 'None'],
#  243: ['Water', 'None'],
#  244: ['Ice', 'Flying'],
#  245: ['Water', 'Flying'],
#  246: ['Steel', 'Flying'],
#  247: ['Dark', 'Fire'],
#  248: ['Dark', 'Fire'],
#  249: ['Dark', 'Fire'],
#  250: ['Water', 'Dragon'],
#  251: ['Ground', 'None'],
#  252: ['Ground', 'None'],
#  253: ['Normal', 'None'],
#  254: ['Normal', 'None'],
#  255: ['Normal', 'None'],
#  256: ['Fighting', 'None'],
#  257: ['Fighting', 'None'],
#  258: ['Ice', 'Psychic'],
#  259: ['Electric', 'None'],
#  260: ['Fire', 'None'],
#  261: ['Normal', 'None'],
#  262: ['Normal', 'None'],
#  263: ['Electric', 'None'],
#  264: ['Fire', 'None'],
#  265: ['Water', 'None'],
#  266: ['Rock', 'Ground'],
#  267: ['Rock', 'Ground'],
#  268: ['Rock', 'Dark'],
#  269: ['Rock', 'Dark'],
#  270: ['Psychic', 'Flying'],
#  271: ['Fire', 'Flying'],
#  272: ['Psychic', 'Grass'],
#  273: ['Grass', 'None'],
#  274: ['Grass', 'None'],
#  275: ['Grass', 'None'],
#  276: ['Grass', 'Dragon'],
#  277: ['Fire', 'None'],
#  278: ['Fire', 'Fighting'],
#  279: ['Fire', 'Fighting'],
#  280: ['Fire', 'Fighting'],
#  281: ['Water', 'None'],
#  282: ['Water', 'Ground'],
#  283: ['Water', 'Ground'],
#  284: ['Water', 'Ground'],
#  285: ['Dark', 'None'],
#  286: ['Dark', 'None'],
#  287: ['Normal', 'None'],
#  288: ['Normal', 'None'],
#  289: ['Bug', 'None'],
#  290: ['Bug', 'None'],
#  291: ['Bug', 'Flying'],
#  292: ['Bug', 'None'],
#  293: ['Bug', 'Poison'],
#  294: ['Water', 'Grass'],
#  295: ['Water', 'Grass'],
#  296: ['Water', 'Grass'],
#  297: ['Grass', 'None'],
#  298: ['Grass', 'Dark'],
#  299: ['Grass', 'Dark'],
#  300: ['Normal', 'Flying'],
#  301: ['Normal', 'Flying'],
#  302: ['Water', 'Flying'],
#  303: ['Water', 'Flying'],
#  304: ['Psychic', 'Fairy'],
#  305: ['Psychic', 'Fairy'],
#  306: ['Psychic', 'Fairy'],
#  307: ['Psychic', 'Fairy'],
#  308: ['Bug', 'Water'],
#  309: ['Bug', 'Flying'],
#  310: ['Grass', 'None'],
#  311: ['Grass', 'Fighting'],
#  312: ['Normal', 'None'],
#  313: ['Normal', 'None'],
#  314: ['Normal', 'None'],
#  315: ['Bug', 'Ground'],
#  316: ['Bug', 'Flying'],
#  317: ['Bug', 'Ghost'],
#  318: ['Normal', 'None'],
#  319: ['Normal', 'None'],
#  320: ['Normal', 'None'],
#  321: ['Fighting', 'None'],
#  322: ['Fighting', 'None'],
#  323: ['Normal', 'Fairy'],
#  324: ['Rock', 'None'],
#  325: ['Normal', 'None'],
#  326: ['Normal', 'None'],
#  327: ['Dark', 'Ghost'],
#  328: ['Dark', 'Ghost'],
#  329: ['Steel', 'Fairy'],
#  330: ['Steel', 'Fairy'],
#  331: ['Steel', 'Rock'],
#  332: ['Steel', 'Rock'],
#  333: ['Steel', 'Rock'],
#  334: ['Steel', 'None'],
#  335: ['Fighting', 'Psychic'],
#  336: ['Fighting', 'Psychic'],
#  337: ['Fighting', 'Psychic'],
#  338: ['Electric', 'None'],
#  339: ['Electric', 'None'],
#  340: ['Electric', 'None'],
#  341: ['Electric', 'None'],
#  342: ['Electric', 'None'],
#  343: ['Bug', 'None'],
#  344: ['Bug', 'None'],
#  345: ['Grass', 'Poison'],
#  346: ['Poison', 'None'],
#  347: ['Poison', 'None'],
#  348: ['Water', 'Dark'],
#  349: ['Water', 'Dark'],
#  350: ['Water', 'Dark'],
#  351: ['Water', 'None'],
#  352: ['Water', 'None'],
#  353: ['Fire', 'Ground'],
#  354: ['Fire', 'Ground'],
#  355: ['Fire', 'Ground'],
#  356: ['Fire', 'None'],
#  357: ['Psychic', 'None'],
#  358: ['Psychic', 'None'],
#  359: ['Normal', 'None'],
#  360: ['Ground', 'None'],
#  361: ['Ground', 'Dragon'],
#  362: ['Ground', 'Dragon'],
#  363: ['Grass', 'None'],
#  364: ['Grass', 'Dark'],
#  365: ['Normal', 'Flying'],
#  366: ['Dragon', 'Flying'],
#  367: ['Dragon', 'Fairy'],
#  368: ['Normal', 'None'],
#  369: ['Poison', 'None'],
#  370: ['Rock', 'Psychic'],
#  371: ['Rock', 'Psychic'],
#  372: ['Water', 'Ground'],
#  373: ['Water', 'Ground'],
#  374: ['Water', 'None'],
#  375: ['Water', 'Dark'],
#  376: ['Ground', 'Psychic'],
#  377: ['Ground', 'Psychic'],
#  378: ['Rock', 'Grass'],
#  379: ['Rock', 'Grass'],
#  380: ['Rock', 'Bug'],
#  381: ['Rock', 'Bug'],
#  382: ['Water', 'None'],
#  383: ['Water', 'None'],
#  384: ['Normal', 'None'],
#  385: ['Normal', 'None'],
#  386: ['Ghost', 'None'],
#  387: ['Ghost', 'None'],
#  388: ['Ghost', 'None'],
#  389: ['Ghost', 'None'],
#  390: ['Ghost', 'None'],
#  391: ['Grass', 'Flying'],
#  392: ['Psychic', 'None'],
#  393: ['Dark', 'None'],
#  394: ['Dark', 'None'],
#  395: ['Psychic', 'None'],
#  396: ['Ice', 'None'],
#  397: ['Ice', 'None'],
#  398: ['Ice', 'None'],
#  399: ['Ice', 'Water'],
#  400: ['Ice', 'Water'],
#  401: ['Ice', 'Water'],
#  402: ['Water', 'None'],
#  403: ['Water', 'None'],
#  404: ['Water', 'None'],
#  405: ['Water', 'Rock'],
#  406: ['Water', 'None'],
#  407: ['Dragon', 'None'],
#  408: ['Dragon', 'None'],
#  409: ['Dragon', 'Flying'],
#  410: ['Dragon', 'Flying'],
#  411: ['Steel', 'Psychic'],
#  412: ['Steel', 'Psychic'],
#  413: ['Steel', 'Psychic'],
#  414: ['Steel', 'Psychic'],
#  415: ['Rock', 'None'],
#  416: ['Ice', 'None'],
#  417: ['Steel', 'None'],
#  418: ['Dragon', 'Psychic'],
#  419: ['Dragon', 'Psychic'],
#  420: ['Dragon', 'Psychic'],
#  421: ['Dragon', 'Psychic'],
#  422: ['Water', 'None'],
#  423: ['Water', 'None'],
#  424: ['Ground', 'None'],
#  425: ['Ground', 'Fire'],
#  426: ['Dragon', 'Flying'],
#  427: ['Dragon', 'Flying'],
#  428: ['Steel', 'Psychic'],
#  429: ['Psychic', 'None'],
#  430: ['Psychic', 'None'],
#  431: ['Psychic', 'None'],
#  432: ['Psychic', 'None'],
#  433: ['Grass', 'None'],
#  434: ['Grass', 'None'],
#  435: ['Grass', 'Ground'],
#  436: ['Fire', 'None'],
#  437: ['Fire', 'Fighting'],
#  438: ['Fire', 'Fighting'],
#  439: ['Water', 'None'],
#  440: ['Water', 'None'],
#  441: ['Water', 'Steel'],
#  442: ['Normal', 'Flying'],
#  443: ['Normal', 'Flying'],
#  444: ['Normal', 'Flying'],
#  445: ['Normal', 'None'],
#  446: ['Normal', 'Water'],
#  447: ['Bug', 'None'],
#  448: ['Bug', 'None'],
#  449: ['Electric', 'None'],
#  450: ['Electric', 'None'],
#  451: ['Electric', 'None'],
#  452: ['Grass', 'Poison'],
#  453: ['Grass', 'Poison'],
#  454: ['Rock', 'None'],
#  455: ['Rock', 'None'],
#  456: ['Rock', 'Steel'],
#  457: ['Rock', 'Steel'],
#  458: ['Bug', 'None'],
#  459: ['Bug', 'Grass'],
#  460: ['Bug', 'Ground'],
#  461: ['Bug', 'Steel'],
#  462: ['Bug', 'Flying'],
#  463: ['Bug', 'Flying'],
#  464: ['Bug', 'Flying'],
#  465: ['Electric', 'None'],
#  466: ['Water', 'None'],
#  467: ['Water', 'None'],
#  468: ['Grass', 'None'],
#  469: ['Grass', 'None'],
#  470: ['Water', 'None'],
#  471: ['Water', 'Ground'],
#  472: ['Normal', 'None'],
#  473: ['Ghost', 'Flying'],
#  474: ['Ghost', 'Flying'],
#  475: ['Normal', 'None'],
#  476: ['Normal', 'None'],
#  477: ['Normal', 'Fighting'],
#  478: ['Ghost', 'None'],
#  479: ['Dark', 'Flying'],
#  480: ['Normal', 'None'],
#  481: ['Normal', 'None'],
#  482: ['Psychic', 'None'],
#  483: ['Poison', 'Dark'],
#  484: ['Poison', 'Dark'],
#  485: ['Steel', 'Psychic'],
#  486: ['Steel', 'Psychic'],
#  487: ['Rock', 'None'],
#  488: ['Psychic', 'Fairy'],
#  489: ['Normal', 'None'],
#  490: ['Normal', 'Flying'],
#  491: ['Ghost', 'Dark'],
#  492: ['Dragon', 'Ground'],
#  493: ['Dragon', 'Ground'],
#  494: ['Dragon', 'Ground'],
#  495: ['Dragon', 'Ground'],
#  496: ['Normal', 'None'],
#  497: ['Fighting', 'None'],
#  498: ['Fighting', 'Steel'],
#  499: ['Fighting', 'Steel'],
#  500: ['Ground', 'None'],
#  501: ['Ground', 'None'],
#  502: ['Poison', 'Bug'],
#  503: ['Poison', 'Dark'],
#  504: ['Poison', 'Fighting'],
#  505: ['Poison', 'Fighting'],
#  506: ['Grass', 'None'],
#  507: ['Water', 'None'],
#  508: ['Water', 'None'],
#  509: ['Water', 'Flying'],
#  510: ['Grass', 'Ice'],
#  511: ['Grass', 'Ice'],
#  512: ['Grass', 'Ice'],
#  513: ['Dark', 'Ice'],
#  514: ['Electric', 'Steel'],
#  515: ['Normal', 'None'],
#  516: ['Ground', 'Rock'],
#  517: ['Grass', 'None'],
#  518: ['Electric', 'None'],
#  519: ['Fire', 'None'],
#  520: ['Fairy', 'Flying'],
#  521: ['Bug', 'Flying'],
#  522: ['Grass', 'None'],
#  523: ['Ice', 'None'],
#  524: ['Ground', 'Flying'],
#  525: ['Ice', 'Ground'],
#  526: ['Normal', 'None'],
#  527: ['Psychic', 'Fighting'],
#  528: ['Psychic', 'Fighting'],
#  529: ['Rock', 'Steel'],
#  530: ['Ghost', 'None'],
#  531: ['Ice', 'Ghost'],
#  532: ['Electric', 'Ghost'],
#  533: ['Electric', 'Fire'],
#  534: ['Electric', 'Water'],
#  535: ['Electric', 'Ice'],
#  536: ['Electric', 'Flying'],
#  537: ['Electric', 'Grass'],
#  538: ['Psychic', 'None'],
#  539: ['Psychic', 'None'],
#  540: ['Psychic', 'None'],
#  541: ['Steel', 'Dragon'],
#  542: ['Water', 'Dragon'],
#  543: ['Fire', 'Steel'],
#  544: ['Normal', 'None'],
#  545: ['Ghost', 'Dragon'],
#  546: ['Ghost', 'Dragon'],
#  547: ['Psychic', 'None'],
#  548: ['Water', 'None'],
#  549: ['Water', 'None'],
#  550: ['Dark', 'None'],
#  551: ['Grass', 'None'],
#  552: ['Grass', 'Flying'],
#  553: ['Normal', 'None'],
#  554: ['Psychic', 'Fire'],
#  555: ['Grass', 'None'],
#  556: ['Grass', 'None'],
#  557: ['Grass', 'None'],
#  558: ['Fire', 'None'],
#  559: ['Fire', 'Fighting'],
#  560: ['Fire', 'Fighting'],
#  561: ['Water', 'None'],
#  562: ['Water', 'None'],
#  563: ['Water', 'None'],
#  564: ['Normal', 'None'],
#  565: ['Normal', 'None'],
#  566: ['Normal', 'None'],
#  567: ['Normal', 'None'],
#  568: ['Normal', 'None'],
#  569: ['Dark', 'None'],
#  570: ['Dark', 'None'],
#  571: ['Grass', 'None'],
#  572: ['Grass', 'None'],
#  573: ['Fire', 'None'],
#  574: ['Fire', 'None'],
#  575: ['Water', 'None'],
#  576: ['Water', 'None'],
#  577: ['Psychic', 'None'],
#  578: ['Psychic', 'None'],
#  579: ['Normal', 'Flying'],
#  580: ['Normal', 'Flying'],
#  581: ['Normal', 'Flying'],
#  582: ['Electric', 'None'],
#  583: ['Electric', 'None'],
#  584: ['Rock', 'None'],
#  585: ['Rock', 'None'],
#  586: ['Rock', 'None'],
#  587: ['Psychic', 'Flying'],
#  588: ['Psychic', 'Flying'],
#  589: ['Ground', 'None'],
#  590: ['Ground', 'Steel'],
#  591: ['Normal', 'None'],
#  592: ['Normal', 'Fairy'],
#  593: ['Fighting', 'None'],
#  594: ['Fighting', 'None'],
#  595: ['Fighting', 'None'],
#  596: ['Water', 'None'],
#  597: ['Water', 'Ground'],
#  598: ['Water', 'Ground'],
#  599: ['Fighting', 'None'],
#  600: ['Fighting', 'None'],
#  601: ['Bug', 'Grass'],
#  602: ['Bug', 'Grass'],
#  603: ['Bug', 'Grass'],
#  604: ['Bug', 'Poison'],
#  605: ['Bug', 'Poison'],
#  606: ['Bug', 'Poison'],
#  607: ['Grass', 'Fairy'],
#  608: ['Grass', 'Fairy'],
#  609: ['Grass', 'None'],
#  610: ['Grass', 'None'],
#  611: ['Water', 'None'],
#  612: ['Ground', 'Dark'],
#  613: ['Ground', 'Dark'],
#  614: ['Ground', 'Dark'],
#  615: ['Fire', 'None'],
#  616: ['Fire', 'None'],
#  617: ['Fire', 'Psychic'],
#  618: ['Grass', 'None'],
#  619: ['Bug', 'Rock'],
#  620: ['Bug', 'Rock'],
#  621: ['Dark', 'Fighting'],
#  622: ['Dark', 'Fighting'],
#  623: ['Psychic', 'Flying'],
#  624: ['Ghost', 'None'],
#  625: ['Ghost', 'None'],
#  626: ['Water', 'Rock'],
#  627: ['Water', 'Rock'],
#  628: ['Rock', 'Flying'],
#  629: ['Rock', 'Flying'],
#  630: ['Poison', 'None'],
#  631: ['Poison', 'None'],
#  632: ['Dark', 'None'],
#  633: ['Dark', 'None'],
#  634: ['Normal', 'None'],
#  635: ['Normal', 'None'],
#  636: ['Psychic', 'None'],
#  637: ['Psychic', 'None'],
#  638: ['Psychic', 'None'],
#  639: ['Psychic', 'None'],
#  640: ['Psychic', 'None'],
#  641: ['Psychic', 'None'],
#  642: ['Water', 'Flying'],
#  643: ['Water', 'Flying'],
#  644: ['Ice', 'None'],
#  645: ['Ice', 'None'],
#  646: ['Ice', 'None'],
#  647: ['Normal', 'Grass'],
#  648: ['Normal', 'Grass'],
#  649: ['Electric', 'Flying'],
#  650: ['Bug', 'None'],
#  651: ['Bug', 'Steel'],
#  652: ['Grass', 'Poison'],
#  653: ['Grass', 'Poison'],
#  654: ['Water', 'Ghost'],
#  655: ['Water', 'Ghost'],
#  656: ['Water', 'None'],
#  657: ['Bug', 'Electric'],
#  658: ['Bug', 'Electric'],
#  659: ['Grass', 'Steel'],
#  660: ['Grass', 'Steel'],
#  661: ['Steel', 'None'],
#  662: ['Steel', 'None'],
#  663: ['Steel', 'None'],
#  664: ['Electric', 'None'],
#  665: ['Electric', 'None'],
#  666: ['Electric', 'None'],
#  667: ['Psychic', 'None'],
#  668: ['Psychic', 'None'],
#  669: ['Ghost', 'Fire'],
#  670: ['Ghost', 'Fire'],
#  671: ['Ghost', 'Fire'],
#  672: ['Dragon', 'None'],
#  673: ['Dragon', 'None'],
#  674: ['Dragon', 'None'],
#  675: ['Ice', 'None'],
#  676: ['Ice', 'None'],
#  677: ['Ice', 'None'],
#  678: ['Bug', 'None'],
#  679: ['Bug', 'None'],
#  680: ['Ground', 'Electric'],
#  681: ['Fighting', 'None'],
#  682: ['Fighting', 'None'],
#  683: ['Dragon', 'None'],
#  684: ['Ground', 'Ghost'],
#  685: ['Ground', 'Ghost'],
#  686: ['Dark', 'Steel'],
#  687: ['Dark', 'Steel'],
#  688: ['Normal', 'None'],
#  689: ['Normal', 'Flying'],
#  690: ['Normal', 'Flying'],
#  691: ['Dark', 'Flying'],
#  692: ['Dark', 'Flying'],
#  693: ['Fire', 'None'],
#  694: ['Bug', 'Steel'],
#  695: ['Dark', 'Dragon'],
#  696: ['Dark', 'Dragon'],
#  697: ['Dark', 'Dragon'],
#  698: ['Bug', 'Fire'],
#  699: ['Bug', 'Fire'],
#  700: ['Steel', 'Fighting'],
#  701: ['Rock', 'Fighting'],
#  702: ['Grass', 'Fighting'],
#  703: ['Flying', 'None'],
#  704: ['Flying', 'None'],
#  705: ['Electric', 'Flying'],
#  706: ['Electric', 'Flying'],
#  707: ['Dragon', 'Fire'],
#  708: ['Dragon', 'Electric'],
#  709: ['Ground', 'Flying'],
#  710: ['Ground', 'Flying'],
#  711: ['Dragon', 'Ice'],
#  712: ['Dragon', 'Ice'],
#  713: ['Dragon', 'Ice'],
#  714: ['Water', 'Fighting'],
#  715: ['Water', 'Fighting'],
#  716: ['Normal', 'Psychic'],
#  717: ['Normal', 'Fighting'],
#  718: ['Bug', 'Steel'],
#  719: ['Grass', 'None'],
#  720: ['Grass', 'None'],
#  721: ['Grass', 'Fighting'],
#  722: ['Fire', 'None'],
#  723: ['Fire', 'None'],
#  724: ['Fire', 'Psychic'],
#  725: ['Water', 'None'],
#  726: ['Water', 'None'],
#  727: ['Water', 'Dark'],
#  728: ['Normal', 'None'],
#  729: ['Normal', 'Ground'],
#  730: ['Normal', 'Flying'],
#  731: ['Fire', 'Flying'],
#  732: ['Fire', 'Flying'],
#  733: ['Bug', 'None'],
#  734: ['Bug', 'None'],
#  735: ['Bug', 'Flying'],
#  736: ['Fire', 'Normal'],
#  737: ['Fire', 'Normal'],
#  738: ['Fairy', 'None'],
#  739: ['Fairy', 'None'],
#  740: ['Fairy', 'None'],
#  741: ['Grass', 'None'],
#  742: ['Grass', 'None'],
#  743: ['Fighting', 'None'],
#  744: ['Fighting', 'Dark'],
#  745: ['Normal', 'None'],
#  746: ['Psychic', 'None'],
#  747: ['Psychic', 'None'],
#  748: ['Psychic', 'None'],
#  749: ['Steel', 'Ghost'],
#  750: ['Steel', 'Ghost'],
#  751: ['Steel', 'Ghost'],
#  752: ['Steel', 'Ghost'],
#  753: ['Fairy', 'None'],
#  754: ['Fairy', 'None'],
#  755: ['Fairy', 'None'],
#  756: ['Fairy', 'None'],
#  757: ['Dark', 'Psychic'],
#  758: ['Dark', 'Psychic'],
#  759: ['Rock', 'Water'],
#  760: ['Rock', 'Water'],
#  761: ['Poison', 'Water'],
#  762: ['Poison', 'Dragon'],
#  763: ['Water', 'None'],
#  764: ['Water', 'None'],
#  765: ['Electric', 'Normal'],
#  766: ['Electric', 'Normal'],
#  767: ['Rock', 'Dragon'],
#  768: ['Rock', 'Dragon'],
#  769: ['Rock', 'Ice'],
#  770: ['Rock', 'Ice'],
#  771: ['Fairy', 'None'],
#  772: ['Fighting', 'Flying'],
#  773: ['Electric', 'Fairy'],
#  774: ['Rock', 'Fairy'],
#  775: ['Dragon', 'None'],
#  776: ['Dragon', 'None'],
#  777: ['Dragon', 'None'],
#  778: ['Steel', 'Fairy'],
#  779: ['Ghost', 'Grass'],
#  780: ['Ghost', 'Grass'],
#  781: ['Ghost', 'Grass'],
#  782: ['Ghost', 'Grass'],
#  783: ['Ghost', 'Grass'],
#  784: ['Ghost', 'Grass'],
#  785: ['Ghost', 'Grass'],
#  786: ['Ghost', 'Grass'],
#  787: ['Ghost', 'Grass'],
#  788: ['Ghost', 'Grass'],
#  789: ['Ice', 'None'],
#  790: ['Ice', 'None'],
#  791: ['Flying', 'Dragon'],
#  792: ['Flying', 'Dragon'],
#  793: ['Fairy', 'None'],
#  794: ['Dark', 'Flying'],
#  795: ['Dragon', 'Ground'],
#  796: ['Rock', 'Fairy'],
#  797: ['Rock', 'Fairy'],
#  798: ['Psychic', 'Ghost'],
#  799: ['Psychic', 'Dark'],
#  800: ['Fire', 'Water']}

# %%
stats_df = pokemon.drop(['Type 1', 'Type 2', 'Name', 'Generation', 'Total_stats'], axis=1)
stats_dict = stats_df.set_index('Number').T.to_dict('list')
stats_dict
# Out:
# {1: [45, 49, 49, 65, 65, 45, 0],
#  2: [60, 62, 63, 80, 80, 60, 0],
#  3: [80, 82, 83, 100, 100, 80, 0],
#  4: [80, 100, 123, 122, 120, 80, 0],
#  5: [39, 52, 43, 60, 50, 65, 0],
#  6: [58, 64, 58, 80, 65, 80, 0],
#  7: [78, 84, 78, 109, 85, 100, 0],
#  8: [78, 130, 111, 130, 85, 100, 0],
#  9: [78, 104, 78, 159, 115, 100, 0],
#  10: [44, 48, 65, 50, 64, 43, 0],
#  11: [59, 63, 80, 65, 80, 58, 0],
#  12: [79, 83, 100, 85, 105, 78, 0],
#  13: [79, 103, 120, 135, 115, 78, 0],
#  14: [45, 30, 35, 20, 20, 45, 0],
#  15: [50, 20, 55, 25, 25, 30, 0],
#  16: [60, 45, 50, 90, 80, 70, 0],
#  17: [40, 35, 30, 20, 20, 50, 0],
#  18: [45, 25, 50, 25, 25, 35, 0],
#  19: [65, 90, 40, 45, 80, 75, 0],
#  20: [65, 150, 40, 15, 80, 145, 0],
#  21: [40, 45, 40, 35, 35, 56, 0],
#  22: [63, 60, 55, 50, 50, 71, 0],
#  23: [83, 80, 75, 70, 70, 101, 0],
#  24: [83, 80, 80, 135, 80, 121, 0],
#  25: [30, 56, 35, 25, 35, 72, 0],
#  26: [55, 81, 60, 50, 70, 97, 0],
#  27: [40, 60, 30, 31, 31, 70, 0],
#  28: [65, 90, 65, 61, 61, 100, 0],
#  29: [35, 60, 44, 40, 54, 55, 0],
#  30: [60, 85, 69, 65, 79, 80, 0],
#  31: [35, 55, 40, 50, 50, 90, 0],
#  32: [60, 90, 55, 90, 80, 110, 0],
#  33: [50, 75, 85, 20, 30, 40, 0],
#  34: [75, 100, 110, 45, 55, 65, 0],
#  35: [55, 47, 52, 40, 40, 41, 0],
#  36: [70, 62, 67, 55, 55, 56, 0],
#  37: [90, 92, 87, 75, 85, 76, 0],
#  38: [46, 57, 40, 40, 40, 50, 0],
#  39: [61, 72, 57, 55, 55, 65, 0],
#  40: [81, 102, 77, 85, 75, 85, 0],
#  41: [70, 45, 48, 60, 65, 35, 0],
#  42: [95, 70, 73, 95, 90, 60, 0],
#  43: [38, 41, 40, 50, 65, 65, 0],
#  44: [73, 76, 75, 81, 100, 100, 0],
#  45: [115, 45, 20, 45, 25, 20, 0],
#  46: [140, 70, 45, 85, 50, 45, 0],
#  47: [40, 45, 35, 30, 40, 55, 0],
#  48: [75, 80, 70, 65, 75, 90, 0],
#  49: [45, 50, 55, 75, 65, 30, 0],
#  50: [60, 65, 70, 85, 75, 40, 0],
#  51: [75, 80, 85, 110, 90, 50, 0],
#  52: [35, 70, 55, 45, 55, 25, 0],
#  53: [60, 95, 80, 60, 80, 30, 0],
#  54: [60, 55, 50, 40, 55, 45, 0],
#  55: [70, 65, 60, 90, 75, 90, 0],
#  56: [10, 55, 25, 35, 45, 95, 0],
#  57: [35, 80, 50, 50, 70, 120, 0],
#  58: [40, 45, 35, 40, 40, 90, 0],
#  59: [65, 70, 60, 65, 65, 115, 0],
#  60: [50, 52, 48, 65, 50, 55, 0],
#  61: [80, 82, 78, 95, 80, 85, 0],
#  62: [40, 80, 35, 35, 45, 70, 0],
#  63: [65, 105, 60, 60, 70, 95, 0],
#  64: [55, 70, 45, 70, 50, 60, 0],
#  65: [90, 110, 80, 100, 80, 95, 0],
#  66: [40, 50, 40, 40, 40, 90, 0],
#  67: [65, 65, 65, 50, 50, 90, 0],
#  68: [90, 95, 95, 70, 90, 70, 0],
#  69: [25, 20, 15, 105, 55, 90, 0],
#  70: [40, 35, 30, 120, 70, 105, 0],
#  71: [55, 50, 45, 135, 95, 120, 0],
#  72: [55, 50, 65, 175, 95, 150, 0],
#  73: [70, 80, 50, 35, 35, 35, 0],
#  74: [80, 100, 70, 50, 60, 45, 0],
#  75: [90, 130, 80, 65, 85, 55, 0],
#  76: [50, 75, 35, 70, 30, 40, 0],
#  77: [65, 90, 50, 85, 45, 55, 0],
#  78: [80, 105, 65, 100, 70, 70, 0],
#  79: [40, 40, 35, 50, 100, 70, 0],
#  80: [80, 70, 65, 80, 120, 100, 0],
#  81: [40, 80, 100, 30, 30, 20, 0],
#  82: [55, 95, 115, 45, 45, 35, 0],
#  83: [80, 120, 130, 55, 65, 45, 0],
#  84: [50, 85, 55, 65, 65, 90, 0],
#  85: [65, 100, 70, 80, 80, 105, 0],
#  86: [90, 65, 65, 40, 40, 15, 0],
#  87: [95, 75, 110, 100, 80, 30, 0],
#  88: [95, 75, 180, 130, 80, 30, 0],
#  89: [25, 35, 70, 95, 55, 45, 0],
#  90: [50, 60, 95, 120, 70, 70, 0],
#  91: [52, 65, 55, 58, 62, 60, 0],
#  92: [35, 85, 45, 35, 35, 75, 0],
#  93: [60, 110, 70, 60, 60, 100, 0],
#  94: [65, 45, 55, 45, 70, 45, 0],
#  95: [90, 70, 80, 70, 95, 70, 0],
#  96: [80, 80, 50, 40, 50, 25, 0],
#  97: [105, 105, 75, 65, 100, 50, 0],
#  98: [30, 65, 100, 45, 25, 40, 0],
#  99: [50, 95, 180, 85, 45, 70, 0],
#  100: [30, 35, 30, 100, 35, 80, 0],
#  101: [45, 50, 45, 115, 55, 95, 0],
#  102: [60, 65, 60, 130, 75, 110, 0],
#  103: [60, 65, 80, 170, 95, 130, 0],
#  104: [35, 45, 160, 30, 45, 70, 0],
#  105: [60, 48, 45, 43, 90, 42, 0],
#  106: [85, 73, 70, 73, 115, 67, 0],
#  107: [30, 105, 90, 25, 25, 50, 0],
#  108: [55, 130, 115, 50, 50, 75, 0],
#  109: [40, 30, 50, 55, 55, 100, 0],
#  110: [60, 50, 70, 80, 80, 140, 0],
#  111: [60, 40, 80, 60, 45, 40, 0],
#  112: [95, 95, 85, 125, 65, 55, 0],
#  113: [50, 50, 95, 40, 50, 35, 0],
#  114: [60, 80, 110, 50, 80, 45, 0],
#  115: [50, 120, 53, 35, 110, 87, 0],
#  116: [50, 105, 79, 35, 110, 76, 0],
#  117: [90, 55, 75, 60, 75, 30, 0],
#  118: [40, 65, 95, 60, 45, 35, 0],
#  119: [65, 90, 120, 85, 70, 60, 0],
#  120: [80, 85, 95, 30, 30, 25, 0],
#  121: [105, 130, 120, 45, 45, 40, 0],
#  122: [250, 5, 5, 35, 105, 50, 0],
#  123: [65, 55, 115, 100, 40, 60, 0],
#  124: [105, 95, 80, 40, 80, 90, 0],
#  125: [105, 125, 100, 60, 100, 100, 0],
#  126: [30, 40, 70, 70, 25, 60, 0],
#  127: [55, 65, 95, 95, 45, 85, 0],
#  128: [45, 67, 60, 35, 50, 63, 0],
#  129: [80, 92, 65, 65, 80, 68, 0],
#  130: [30, 45, 55, 70, 55, 85, 0],
#  131: [60, 75, 85, 100, 85, 115, 0],
#  132: [40, 45, 65, 100, 120, 90, 0],
#  133: [70, 110, 80, 55, 80, 105, 0],
#  134: [65, 50, 35, 115, 95, 95, 0],
#  135: [65, 83, 57, 95, 85, 105, 0],
#  136: [65, 95, 57, 100, 85, 93, 0],
#  137: [65, 125, 100, 55, 70, 85, 0],
#  138: [65, 155, 120, 65, 90, 105, 0],
#  139: [75, 100, 95, 40, 70, 110, 0],
#  140: [20, 10, 55, 15, 20, 80, 0],
#  141: [95, 125, 79, 60, 100, 81, 0],
#  142: [95, 155, 109, 70, 130, 81, 0],
#  143: [130, 85, 80, 85, 95, 60, 0],
#  144: [48, 48, 48, 48, 48, 48, 0],
#  145: [55, 55, 50, 45, 65, 55, 0],
#  146: [130, 65, 60, 110, 95, 65, 0],
#  147: [65, 65, 60, 110, 95, 130, 0],
#  148: [65, 130, 60, 95, 110, 65, 0],
#  149: [65, 60, 70, 85, 75, 40, 0],
#  150: [35, 40, 100, 90, 55, 35, 0],
#  151: [70, 60, 125, 115, 70, 55, 0],
#  152: [30, 80, 90, 55, 45, 55, 0],
#  153: [60, 115, 105, 65, 70, 80, 0],
#  154: [80, 105, 65, 60, 75, 130, 0],
#  155: [80, 135, 85, 70, 95, 150, 0],
#  156: [160, 110, 65, 65, 110, 30, 0],
#  157: [90, 85, 100, 95, 125, 85, 1],
#  158: [90, 90, 85, 125, 90, 100, 1],
#  159: [90, 100, 90, 125, 85, 90, 1],
#  160: [41, 64, 45, 50, 50, 50, 0],
#  161: [61, 84, 65, 70, 70, 70, 0],
#  162: [91, 134, 95, 100, 100, 80, 0],
#  163: [106, 110, 90, 154, 90, 130, 1],
#  164: [106, 190, 100, 154, 100, 130, 1],
#  165: [106, 150, 70, 194, 120, 140, 1],
#  166: [100, 100, 100, 100, 100, 100, 0],
#  167: [45, 49, 65, 49, 65, 45, 0],
#  168: [60, 62, 80, 63, 80, 60, 0],
#  169: [80, 82, 100, 83, 100, 80, 0],
#  170: [39, 52, 43, 60, 50, 65, 0],
#  171: [58, 64, 58, 80, 65, 80, 0],
#  172: [78, 84, 78, 109, 85, 100, 0],
#  173: [50, 65, 64, 44, 48, 43, 0],
#  174: [65, 80, 80, 59, 63, 58, 0],
#  175: [85, 105, 100, 79, 83, 78, 0],
#  176: [35, 46, 34, 35, 45, 20, 0],
#  177: [85, 76, 64, 45, 55, 90, 0],
#  178: [60, 30, 30, 36, 56, 50, 0],
#  179: [100, 50, 50, 76, 96, 70, 0],
#  180: [40, 20, 30, 40, 80, 55, 0],
#  181: [55, 35, 50, 55, 110, 85, 0],
#  182: [40, 60, 40, 40, 40, 30, 0],
#  183: [70, 90, 70, 60, 60, 40, 0],
#  184: [85, 90, 80, 70, 80, 130, 0],
#  185: [75, 38, 38, 56, 56, 67, 0],
#  186: [125, 58, 58, 76, 76, 67, 0],
#  187: [20, 40, 15, 35, 35, 60, 0],
#  188: [50, 25, 28, 45, 55, 15, 0],
#  189: [90, 30, 15, 40, 20, 15, 0],
#  190: [35, 20, 65, 40, 65, 20, 0],
#  191: [55, 40, 85, 80, 105, 40, 0],
#  192: [40, 50, 45, 70, 45, 70, 0],
#  193: [65, 75, 70, 95, 70, 95, 0],
#  194: [55, 40, 40, 65, 45, 35, 0],
#  195: [70, 55, 55, 80, 60, 45, 0],
#  196: [90, 75, 85, 115, 90, 55, 0],
#  197: [90, 95, 105, 165, 110, 45, 0],
#  198: [75, 80, 95, 90, 100, 50, 0],
#  199: [70, 20, 50, 20, 50, 40, 0],
#  200: [100, 50, 80, 60, 80, 50, 0],
#  201: [70, 100, 115, 30, 65, 30, 0],
#  202: [90, 75, 75, 90, 100, 70, 0],
#  203: [35, 35, 40, 35, 55, 50, 0],
#  204: [55, 45, 50, 45, 65, 80, 0],
#  205: [75, 55, 70, 55, 95, 110, 0],
#  206: [55, 70, 55, 40, 55, 85, 0],
#  207: [30, 30, 30, 30, 30, 30, 0],
#  208: [75, 75, 55, 105, 85, 30, 0],
#  209: [65, 65, 45, 75, 45, 95, 0],
#  210: [55, 45, 45, 25, 25, 15, 0],
#  211: [95, 85, 85, 65, 65, 35, 0],
#  212: [65, 65, 60, 130, 95, 110, 0],
#  213: [95, 65, 110, 60, 130, 65, 0],
#  214: [60, 85, 42, 85, 42, 91, 0],
#  215: [95, 75, 80, 100, 110, 30, 0],
#  216: [60, 60, 60, 85, 85, 85, 0],
#  217: [48, 72, 48, 72, 48, 48, 0],
#  218: [190, 33, 58, 33, 58, 33, 0],
#  219: [70, 80, 65, 90, 65, 85, 0],
#  220: [50, 65, 90, 35, 35, 15, 0],
#  221: [75, 90, 140, 60, 60, 40, 0],
#  222: [100, 70, 70, 65, 65, 45, 0],
#  223: [65, 75, 105, 35, 65, 85, 0],
#  224: [75, 85, 200, 55, 65, 30, 0],
#  225: [75, 125, 230, 55, 95, 30, 0],
#  226: [60, 80, 50, 40, 40, 30, 0],
#  227: [90, 120, 75, 60, 60, 45, 0],
#  228: [65, 95, 75, 55, 55, 85, 0],
#  229: [70, 130, 100, 55, 80, 65, 0],
#  230: [70, 150, 140, 65, 100, 75, 0],
#  231: [20, 10, 230, 10, 230, 5, 0],
#  232: [80, 125, 75, 40, 95, 85, 0],
#  233: [80, 185, 115, 40, 105, 75, 0],
#  234: [55, 95, 55, 35, 75, 115, 0],
#  235: [60, 80, 50, 50, 50, 40, 0],
#  236: [90, 130, 75, 75, 75, 55, 0],
#  237: [40, 40, 40, 70, 40, 20, 0],
#  238: [50, 50, 120, 80, 80, 30, 0],
#  239: [50, 50, 40, 30, 30, 50, 0],
#  240: [100, 100, 80, 60, 60, 50, 0],
#  241: [55, 55, 85, 65, 85, 35, 0],
#  242: [35, 65, 35, 65, 35, 65, 0],
#  243: [75, 105, 75, 105, 75, 45, 0],
#  244: [45, 55, 45, 65, 45, 75, 0],
#  245: [65, 40, 70, 80, 140, 70, 0],
#  246: [65, 80, 140, 40, 70, 70, 0],
#  247: [45, 60, 30, 80, 50, 65, 0],
#  248: [75, 90, 50, 110, 80, 95, 0],
#  249: [75, 90, 90, 140, 90, 115, 0],
#  250: [75, 95, 95, 95, 95, 85, 0],
#  251: [90, 60, 60, 40, 40, 40, 0],
#  252: [90, 120, 120, 60, 60, 50, 0],
#  253: [85, 80, 90, 105, 95, 60, 0],
#  254: [73, 95, 62, 85, 65, 85, 0],
#  255: [55, 20, 35, 20, 45, 75, 0],
#  256: [35, 35, 35, 35, 35, 35, 0],
#  257: [50, 95, 95, 35, 110, 70, 0],
#  258: [45, 30, 15, 85, 65, 65, 0],
#  259: [45, 63, 37, 65, 55, 95, 0],
#  260: [45, 75, 37, 70, 55, 83, 0],
#  261: [95, 80, 105, 40, 70, 100, 0],
#  262: [255, 10, 10, 75, 135, 55, 0],
#  263: [90, 85, 75, 115, 100, 115, 1],
#  264: [115, 115, 85, 90, 75, 100, 1],
#  265: [100, 75, 115, 90, 115, 85, 1],
#  266: [50, 64, 50, 45, 50, 41, 0],
#  267: [70, 84, 70, 65, 70, 51, 0],
#  268: [100, 134, 110, 95, 100, 61, 0],
#  269: [100, 164, 150, 95, 120, 71, 0],
#  270: [106, 90, 130, 90, 154, 110, 1],
#  271: [106, 130, 90, 110, 154, 90, 1],
#  272: [100, 100, 100, 100, 100, 100, 0],
#  273: [40, 45, 35, 65, 55, 70, 0],
#  274: [50, 65, 45, 85, 65, 95, 0],
#  275: [70, 85, 65, 105, 85, 120, 0],
#  276: [70, 110, 75, 145, 85, 145, 0],
#  277: [45, 60, 40, 70, 50, 45, 0],
#  278: [60, 85, 60, 85, 60, 55, 0],
#  279: [80, 120, 70, 110, 70, 80, 0],
#  280: [80, 160, 80, 130, 80, 100, 0],
#  281: [50, 70, 50, 50, 50, 40, 0],
#  282: [70, 85, 70, 60, 70, 50, 0],
#  283: [100, 110, 90, 85, 90, 60, 0],
#  284: [100, 150, 110, 95, 110, 70, 0],
#  285: [35, 55, 35, 30, 30, 35, 0],
#  286: [70, 90, 70, 60, 60, 70, 0],
#  287: [38, 30, 41, 30, 41, 60, 0],
#  288: [78, 70, 61, 50, 61, 100, 0],
#  289: [45, 45, 35, 20, 30, 20, 0],
#  290: [50, 35, 55, 25, 25, 15, 0],
#  291: [60, 70, 50, 100, 50, 65, 0],
#  292: [50, 35, 55, 25, 25, 15, 0],
#  293: [60, 50, 70, 50, 90, 65, 0],
#  294: [40, 30, 30, 40, 50, 30, 0],
#  295: [60, 50, 50, 60, 70, 50, 0],
#  296: [80, 70, 70, 90, 100, 70, 0],
#  297: [40, 40, 50, 30, 30, 30, 0],
#  298: [70, 70, 40, 60, 40, 60, 0],
#  299: [90, 100, 60, 90, 60, 80, 0],
#  300: [40, 55, 30, 30, 30, 85, 0],
#  301: [60, 85, 60, 50, 50, 125, 0],
#  302: [40, 30, 30, 55, 30, 85, 0],
#  303: [60, 50, 100, 85, 70, 65, 0],
#  304: [28, 25, 25, 45, 35, 40, 0],
#  305: [38, 35, 35, 65, 55, 50, 0],
#  306: [68, 65, 65, 125, 115, 80, 0],
#  307: [68, 85, 65, 165, 135, 100, 0],
#  308: [40, 30, 32, 50, 52, 65, 0],
#  309: [70, 60, 62, 80, 82, 60, 0],
#  310: [60, 40, 60, 40, 60, 35, 0],
#  311: [60, 130, 80, 60, 60, 70, 0],
#  312: [60, 60, 60, 35, 35, 30, 0],
#  313: [80, 80, 80, 55, 55, 90, 0],
#  314: [150, 160, 100, 95, 65, 100, 0],
#  315: [31, 45, 90, 30, 30, 40, 0],
#  316: [61, 90, 45, 50, 50, 160, 0],
#  317: [1, 90, 45, 30, 30, 40, 0],
#  318: [64, 51, 23, 51, 23, 28, 0],
#  319: [84, 71, 43, 71, 43, 48, 0],
#  320: [104, 91, 63, 91, 73, 68, 0],
#  321: [72, 60, 30, 20, 30, 25, 0],
#  322: [144, 120, 60, 40, 60, 50, 0],
#  323: [50, 20, 40, 20, 40, 20, 0],
#  324: [30, 45, 135, 45, 90, 30, 0],
#  325: [50, 45, 45, 35, 35, 50, 0],
#  326: [70, 65, 65, 55, 55, 70, 0],
#  327: [50, 75, 75, 65, 65, 50, 0],
#  328: [50, 85, 125, 85, 115, 20, 0],
#  329: [50, 85, 85, 55, 55, 50, 0],
#  330: [50, 105, 125, 55, 95, 50, 0],
#  331: [50, 70, 100, 40, 40, 30, 0],
#  332: [60, 90, 140, 50, 50, 40, 0],
#  333: [70, 110, 180, 60, 60, 50, 0],
#  334: [70, 140, 230, 60, 80, 50, 0],
#  335: [30, 40, 55, 40, 55, 60, 0],
#  336: [60, 60, 75, 60, 75, 80, 0],
#  337: [60, 100, 85, 80, 85, 100, 0],
#  338: [40, 45, 40, 65, 40, 65, 0],
#  339: [70, 75, 60, 105, 60, 105, 0],
#  340: [70, 75, 80, 135, 80, 135, 0],
#  341: [60, 50, 40, 85, 75, 95, 0],
#  342: [60, 40, 50, 75, 85, 95, 0],
#  343: [65, 73, 55, 47, 75, 85, 0],
#  344: [65, 47, 55, 73, 75, 85, 0],
#  345: [50, 60, 45, 100, 80, 65, 0],
#  346: [70, 43, 53, 43, 53, 40, 0],
#  347: [100, 73, 83, 73, 83, 55, 0],
#  348: [45, 90, 20, 65, 20, 65, 0],
#  349: [70, 120, 40, 95, 40, 95, 0],
#  350: [70, 140, 70, 110, 65, 105, 0],
#  351: [130, 70, 35, 70, 35, 60, 0],
#  352: [170, 90, 45, 90, 45, 60, 0],
#  353: [60, 60, 40, 65, 45, 35, 0],
#  354: [70, 100, 70, 105, 75, 40, 0],
#  355: [70, 120, 100, 145, 105, 20, 0],
#  356: [70, 85, 140, 85, 70, 20, 0],
#  357: [60, 25, 35, 70, 80, 60, 0],
#  358: [80, 45, 65, 90, 110, 80, 0],
#  359: [60, 60, 60, 60, 60, 60, 0],
#  360: [45, 100, 45, 45, 45, 10, 0],
#  361: [50, 70, 50, 50, 50, 70, 0],
#  362: [80, 100, 80, 80, 80, 100, 0],
#  363: [50, 85, 40, 85, 40, 35, 0],
#  364: [70, 115, 60, 115, 60, 55, 0],
#  365: [45, 40, 60, 40, 75, 50, 0],
#  366: [75, 70, 90, 70, 105, 80, 0],
#  367: [75, 110, 110, 110, 105, 80, 0],
#  368: [73, 115, 60, 60, 60, 90, 0],
#  369: [73, 100, 60, 100, 60, 65, 0],
#  370: [70, 55, 65, 95, 85, 70, 0],
#  371: [70, 95, 85, 55, 65, 70, 0],
#  372: [50, 48, 43, 46, 41, 60, 0],
#  373: [110, 78, 73, 76, 71, 60, 0],
#  374: [43, 80, 65, 50, 35, 35, 0],
#  375: [63, 120, 85, 90, 55, 55, 0],
#  376: [40, 40, 55, 40, 70, 55, 0],
#  377: [60, 70, 105, 70, 120, 75, 0],
#  378: [66, 41, 77, 61, 87, 23, 0],
#  379: [86, 81, 97, 81, 107, 43, 0],
#  380: [45, 95, 50, 40, 50, 75, 0],
#  381: [75, 125, 100, 70, 80, 45, 0],
#  382: [20, 15, 20, 10, 55, 80, 0],
#  383: [95, 60, 79, 100, 125, 81, 0],
#  384: [70, 70, 70, 70, 70, 70, 0],
#  385: [60, 90, 70, 60, 120, 40, 0],
#  386: [44, 75, 35, 63, 33, 45, 0],
#  387: [64, 115, 65, 83, 63, 65, 0],
#  388: [64, 165, 75, 93, 83, 75, 0],
#  389: [20, 40, 90, 30, 90, 25, 0],
#  390: [40, 70, 130, 60, 130, 25, 0],
#  391: [99, 68, 83, 72, 87, 51, 0],
#  392: [65, 50, 70, 95, 80, 65, 0],
#  393: [65, 130, 60, 75, 60, 75, 0],
#  394: [65, 150, 60, 115, 60, 115, 0],
#  395: [95, 23, 48, 23, 48, 23, 0],
#  396: [50, 50, 50, 50, 50, 50, 0],
#  397: [80, 80, 80, 80, 80, 80, 0],
#  398: [80, 120, 80, 120, 80, 100, 0],
#  399: [70, 40, 50, 55, 50, 25, 0],
#  400: [90, 60, 70, 75, 70, 45, 0],
#  401: [110, 80, 90, 95, 90, 65, 0],
#  402: [35, 64, 85, 74, 55, 32, 0],
#  403: [55, 104, 105, 94, 75, 52, 0],
#  404: [55, 84, 105, 114, 75, 52, 0],
#  405: [100, 90, 130, 45, 65, 55, 0],
#  406: [43, 30, 55, 40, 65, 97, 0],
#  407: [45, 75, 60, 40, 30, 50, 0],
#  408: [65, 95, 100, 60, 50, 50, 0],
#  409: [95, 135, 80, 110, 80, 100, 0],
#  410: [95, 145, 130, 120, 90, 120, 0],
#  411: [40, 55, 80, 35, 60, 30, 0],
#  412: [60, 75, 100, 55, 80, 50, 0],
#  413: [80, 135, 130, 95, 90, 70, 0],
#  414: [80, 145, 150, 105, 110, 110, 0],
#  415: [80, 100, 200, 50, 100, 50, 1],
#  416: [80, 50, 100, 100, 200, 50, 1],
#  417: [80, 75, 150, 75, 150, 50, 1],
#  418: [80, 80, 90, 110, 130, 110, 1],
#  419: [80, 100, 120, 140, 150, 110, 1],
#  420: [80, 90, 80, 130, 110, 110, 1],
#  421: [80, 130, 100, 160, 120, 110, 1],
#  422: [100, 100, 90, 150, 140, 90, 1],
#  423: [100, 150, 90, 180, 160, 90, 1],
#  424: [100, 150, 140, 100, 90, 90, 1],
#  425: [100, 180, 160, 150, 90, 90, 1],
#  426: [105, 150, 90, 150, 90, 95, 1],
#  427: [105, 180, 100, 180, 100, 115, 1],
#  428: [100, 100, 100, 100, 100, 100, 1],
#  429: [50, 150, 50, 150, 50, 150, 1],
#  430: [50, 180, 20, 180, 20, 150, 1],
#  431: [50, 70, 160, 70, 160, 90, 1],
#  432: [50, 95, 90, 95, 90, 180, 1],
#  433: [55, 68, 64, 45, 55, 31, 0],
#  434: [75, 89, 85, 55, 65, 36, 0],
#  435: [95, 109, 105, 75, 85, 56, 0],
#  436: [44, 58, 44, 58, 44, 61, 0],
#  437: [64, 78, 52, 78, 52, 81, 0],
#  438: [76, 104, 71, 104, 71, 108, 0],
#  439: [53, 51, 53, 61, 56, 40, 0],
#  440: [64, 66, 68, 81, 76, 50, 0],
#  441: [84, 86, 88, 111, 101, 60, 0],
#  442: [40, 55, 30, 30, 30, 60, 0],
#  443: [55, 75, 50, 40, 40, 80, 0],
#  444: [85, 120, 70, 50, 60, 100, 0],
#  445: [59, 45, 40, 35, 40, 31, 0],
#  446: [79, 85, 60, 55, 60, 71, 0],
#  447: [37, 25, 41, 25, 41, 25, 0],
#  448: [77, 85, 51, 55, 51, 65, 0],
#  449: [45, 65, 34, 40, 34, 45, 0],
#  450: [60, 85, 49, 60, 49, 60, 0],
#  451: [80, 120, 79, 95, 79, 70, 0],
#  452: [40, 30, 35, 50, 70, 55, 0],
#  453: [60, 70, 65, 125, 105, 90, 0],
#  454: [67, 125, 40, 30, 30, 58, 0],
#  455: [97, 165, 60, 65, 50, 58, 0],
#  456: [30, 42, 118, 42, 88, 30, 0],
#  457: [60, 52, 168, 47, 138, 30, 0],
#  458: [40, 29, 45, 29, 45, 36, 0],
#  459: [60, 59, 85, 79, 105, 36, 0],
#  460: [60, 79, 105, 59, 85, 36, 0],
#  461: [60, 69, 95, 69, 95, 36, 0],
#  462: [70, 94, 50, 94, 50, 66, 0],
#  463: [30, 30, 42, 30, 42, 70, 0],
#  464: [70, 80, 102, 80, 102, 40, 0],
#  465: [60, 45, 70, 45, 90, 95, 0],
#  466: [55, 65, 35, 60, 30, 85, 0],
#  467: [85, 105, 55, 85, 50, 115, 0],
#  468: [45, 35, 45, 62, 53, 35, 0],
#  469: [70, 60, 70, 87, 78, 85, 0],
#  470: [76, 48, 48, 57, 62, 34, 0],
#  471: [111, 83, 68, 92, 82, 39, 0],
#  472: [75, 100, 66, 60, 66, 115, 0],
#  473: [90, 50, 34, 60, 44, 70, 0],
#  474: [150, 80, 44, 90, 54, 80, 0],
#  475: [55, 66, 44, 44, 56, 85, 0],
#  476: [65, 76, 84, 54, 96, 105, 0],
#  477: [65, 136, 94, 54, 96, 135, 0],
#  478: [60, 60, 60, 105, 105, 105, 0],
#  479: [100, 125, 52, 105, 52, 71, 0],
#  480: [49, 55, 42, 42, 37, 85, 0],
#  481: [71, 82, 64, 64, 59, 112, 0],
#  482: [45, 30, 50, 65, 50, 45, 0],
#  483: [63, 63, 47, 41, 41, 74, 0],
#  484: [103, 93, 67, 71, 61, 84, 0],
#  485: [57, 24, 86, 24, 86, 23, 0],
#  486: [67, 89, 116, 79, 116, 33, 0],
#  487: [50, 80, 95, 10, 45, 10, 0],
#  488: [20, 25, 45, 70, 90, 60, 0],
#  489: [100, 5, 5, 15, 65, 30, 0],
#  490: [76, 65, 45, 92, 42, 91, 0],
#  491: [50, 92, 108, 92, 108, 35, 0],
#  492: [58, 70, 45, 40, 45, 42, 0],
#  493: [68, 90, 65, 50, 55, 82, 0],
#  494: [108, 130, 95, 80, 85, 102, 0],
#  495: [108, 170, 115, 120, 95, 92, 0],
#  496: [135, 85, 40, 40, 85, 5, 0],
#  497: [40, 70, 40, 35, 40, 60, 0],
#  498: [70, 110, 70, 115, 70, 90, 0],
#  499: [70, 145, 88, 140, 70, 112, 0],
#  500: [68, 72, 78, 38, 42, 32, 0],
#  501: [108, 112, 118, 68, 72, 47, 0],
#  502: [40, 50, 90, 30, 55, 65, 0],
#  503: [70, 90, 110, 60, 75, 95, 0],
#  504: [48, 61, 40, 61, 40, 50, 0],
#  505: [83, 106, 65, 86, 65, 85, 0],
#  506: [74, 100, 72, 90, 72, 46, 0],
#  507: [49, 49, 56, 49, 61, 66, 0],
#  508: [69, 69, 76, 69, 86, 91, 0],
#  509: [45, 20, 50, 60, 120, 50, 0],
#  510: [60, 62, 50, 62, 60, 40, 0],
#  511: [90, 92, 75, 92, 85, 60, 0],
#  512: [90, 132, 105, 132, 105, 30, 0],
#  513: [70, 120, 65, 45, 85, 125, 0],
#  514: [70, 70, 115, 130, 90, 60, 0],
#  515: [110, 85, 95, 80, 95, 50, 0],
#  516: [115, 140, 130, 55, 55, 40, 0],
#  517: [100, 100, 125, 110, 50, 50, 0],
#  518: [75, 123, 67, 95, 85, 95, 0],
#  519: [75, 95, 67, 125, 95, 83, 0],
#  520: [85, 50, 95, 120, 115, 80, 0],
#  521: [86, 76, 86, 116, 56, 95, 0],
#  522: [65, 110, 130, 60, 65, 95, 0],
#  523: [65, 60, 110, 130, 95, 65, 0],
#  524: [75, 95, 125, 45, 75, 95, 0],
#  525: [110, 130, 80, 70, 60, 80, 0],
#  526: [85, 80, 70, 135, 75, 90, 0],
#  527: [68, 125, 65, 65, 115, 80, 0],
#  528: [68, 165, 95, 65, 115, 110, 0],
#  529: [60, 55, 145, 75, 150, 40, 0],
#  530: [45, 100, 135, 65, 135, 45, 0],
#  531: [70, 80, 70, 80, 70, 110, 0],
#  532: [50, 50, 77, 95, 77, 91, 0],
#  533: [50, 65, 107, 105, 107, 86, 0],
#  534: [50, 65, 107, 105, 107, 86, 0],
#  535: [50, 65, 107, 105, 107, 86, 0],
#  536: [50, 65, 107, 105, 107, 86, 0],
#  537: [50, 65, 107, 105, 107, 86, 0],
#  538: [75, 75, 130, 75, 130, 95, 1],
#  539: [80, 105, 105, 105, 105, 80, 1],
#  540: [75, 125, 70, 125, 70, 115, 1],
#  541: [100, 120, 120, 150, 100, 90, 1],
#  542: [90, 120, 100, 150, 120, 100, 1],
#  543: [91, 90, 106, 130, 106, 77, 1],
#  544: [110, 160, 110, 80, 110, 100, 1],
#  545: [150, 100, 120, 100, 120, 90, 1],
#  546: [150, 120, 100, 120, 100, 90, 1],
#  547: [120, 70, 120, 75, 130, 85, 0],
#  548: [80, 80, 80, 80, 80, 80, 0],
#  549: [100, 100, 100, 100, 100, 100, 0],
#  550: [70, 90, 90, 135, 90, 125, 1],
#  551: [100, 100, 100, 100, 100, 100, 1],
#  552: [100, 103, 75, 120, 75, 127, 1],
#  553: [120, 120, 120, 120, 120, 120, 1],
#  554: [100, 100, 100, 100, 100, 100, 1],
#  555: [45, 45, 55, 45, 55, 63, 0],
#  556: [60, 60, 75, 60, 75, 83, 0],
#  557: [75, 75, 95, 75, 95, 113, 0],
#  558: [65, 63, 45, 45, 45, 45, 0],
#  559: [90, 93, 55, 70, 55, 55, 0],
#  560: [110, 123, 65, 100, 65, 65, 0],
#  561: [55, 55, 45, 63, 45, 45, 0],
#  562: [75, 75, 60, 83, 60, 60, 0],
#  563: [95, 100, 85, 108, 70, 70, 0],
#  564: [45, 55, 39, 35, 39, 42, 0],
#  565: [60, 85, 69, 60, 69, 77, 0],
#  566: [45, 60, 45, 25, 45, 55, 0],
#  567: [65, 80, 65, 35, 65, 60, 0],
#  568: [85, 110, 90, 45, 90, 80, 0],
#  569: [41, 50, 37, 50, 37, 66, 0],
#  570: [64, 88, 50, 88, 50, 106, 0],
#  571: [50, 53, 48, 53, 48, 64, 0],
#  572: [75, 98, 63, 98, 63, 101, 0],
#  573: [50, 53, 48, 53, 48, 64, 0],
#  574: [75, 98, 63, 98, 63, 101, 0],
#  575: [50, 53, 48, 53, 48, 64, 0],
#  576: [75, 98, 63, 98, 63, 101, 0],
#  577: [76, 25, 45, 67, 55, 24, 0],
#  578: [116, 55, 85, 107, 95, 29, 0],
#  579: [50, 55, 50, 36, 30, 43, 0],
#  580: [62, 77, 62, 50, 42, 65, 0],
#  581: [80, 115, 80, 65, 55, 93, 0],
#  582: [45, 60, 32, 50, 32, 76, 0],
#  583: [75, 100, 63, 80, 63, 116, 0],
#  584: [55, 75, 85, 25, 25, 15, 0],
#  585: [70, 105, 105, 50, 40, 20, 0],
#  586: [85, 135, 130, 60, 80, 25, 0],
#  587: [55, 45, 43, 55, 43, 72, 0],
#  588: [67, 57, 55, 77, 55, 114, 0],
#  589: [60, 85, 40, 30, 45, 68, 0],
#  590: [110, 135, 60, 50, 65, 88, 0],
#  591: [103, 60, 86, 60, 86, 50, 0],
#  592: [103, 60, 126, 80, 126, 50, 0],
#  593: [75, 80, 55, 25, 35, 35, 0],
#  594: [85, 105, 85, 40, 50, 40, 0],
#  595: [105, 140, 95, 55, 65, 45, 0],
#  596: [50, 50, 40, 50, 40, 64, 0],
#  597: [75, 65, 55, 65, 55, 69, 0],
#  598: [105, 95, 75, 85, 75, 74, 0],
#  599: [120, 100, 85, 30, 85, 45, 0],
#  600: [75, 125, 75, 30, 75, 85, 0],
#  601: [45, 53, 70, 40, 60, 42, 0],
#  602: [55, 63, 90, 50, 80, 42, 0],
#  603: [75, 103, 80, 70, 80, 92, 0],
#  604: [30, 45, 59, 30, 39, 57, 0],
#  605: [40, 55, 99, 40, 79, 47, 0],
#  606: [60, 100, 89, 55, 69, 112, 0],
#  607: [40, 27, 60, 37, 50, 66, 0],
#  608: [60, 67, 85, 77, 75, 116, 0],
#  609: [45, 35, 50, 70, 50, 30, 0],
#  610: [70, 60, 75, 110, 75, 90, 0],
#  611: [70, 92, 65, 80, 55, 98, 0],
#  612: [50, 72, 35, 35, 35, 65, 0],
#  613: [60, 82, 45, 45, 45, 74, 0],
#  614: [95, 117, 80, 65, 70, 92, 0],
#  615: [70, 90, 45, 15, 45, 50, 0],
#  616: [105, 140, 55, 30, 55, 95, 0],
#  617: [105, 30, 105, 140, 105, 55, 0],
#  618: [75, 86, 67, 106, 67, 60, 0],
#  619: [50, 65, 85, 35, 35, 55, 0],
#  620: [70, 95, 125, 65, 75, 45, 0],
#  621: [50, 75, 70, 35, 70, 48, 0],
#  622: [65, 90, 115, 45, 115, 58, 0],
#  623: [72, 58, 80, 103, 80, 97, 0],
#  624: [38, 30, 85, 55, 65, 30, 0],
#  625: [58, 50, 145, 95, 105, 30, 0],
#  626: [54, 78, 103, 53, 45, 22, 0],
#  627: [74, 108, 133, 83, 65, 32, 0],
#  628: [55, 112, 45, 74, 45, 70, 0],
#  629: [75, 140, 65, 112, 65, 110, 0],
#  630: [50, 50, 62, 40, 62, 65, 0],
#  631: [80, 95, 82, 60, 82, 75, 0],
#  632: [40, 65, 40, 80, 40, 65, 0],
#  633: [60, 105, 60, 120, 60, 105, 0],
#  634: [55, 50, 40, 40, 40, 75, 0],
#  635: [75, 95, 60, 65, 60, 115, 0],
#  636: [45, 30, 50, 55, 65, 45, 0],
#  637: [60, 45, 70, 75, 85, 55, 0],
#  638: [70, 55, 95, 95, 110, 65, 0],
#  639: [45, 30, 40, 105, 50, 20, 0],
#  640: [65, 40, 50, 125, 60, 30, 0],
#  641: [110, 65, 75, 125, 85, 30, 0],
#  642: [62, 44, 50, 44, 50, 55, 0],
#  643: [75, 87, 63, 87, 63, 98, 0],
#  644: [36, 50, 50, 65, 60, 44, 0],
#  645: [51, 65, 65, 80, 75, 59, 0],
#  646: [71, 95, 85, 110, 95, 79, 0],
#  647: [60, 60, 50, 40, 50, 75, 0],
#  648: [80, 100, 70, 60, 70, 95, 0],
#  649: [55, 75, 60, 75, 60, 103, 0],
#  650: [50, 75, 45, 40, 45, 60, 0],
#  651: [70, 135, 105, 60, 105, 20, 0],
#  652: [69, 55, 45, 55, 55, 15, 0],
#  653: [114, 85, 70, 85, 80, 30, 0],
#  654: [55, 40, 50, 65, 85, 40, 0],
#  655: [100, 60, 70, 85, 105, 60, 0],
#  656: [165, 75, 80, 40, 45, 65, 0],
#  657: [50, 47, 50, 57, 50, 65, 0],
#  658: [70, 77, 60, 97, 60, 108, 0],
#  659: [44, 50, 91, 24, 86, 10, 0],
#  660: [74, 94, 131, 54, 116, 20, 0],
#  661: [40, 55, 70, 45, 60, 30, 0],
#  662: [60, 80, 95, 70, 85, 50, 0],
#  663: [60, 100, 115, 70, 85, 90, 0],
#  664: [35, 55, 40, 45, 40, 60, 0],
#  665: [65, 85, 70, 75, 70, 40, 0],
#  666: [85, 115, 80, 105, 80, 50, 0],
#  667: [55, 55, 55, 85, 55, 30, 0],
#  668: [75, 75, 75, 125, 95, 40, 0],
#  669: [50, 30, 55, 65, 55, 20, 0],
#  670: [60, 40, 60, 95, 60, 55, 0],
#  671: [60, 55, 90, 145, 90, 80, 0],
#  672: [46, 87, 60, 30, 40, 57, 0],
#  673: [66, 117, 70, 40, 50, 67, 0],
#  674: [76, 147, 90, 60, 70, 97, 0],
#  675: [55, 70, 40, 60, 40, 40, 0],
#  676: [95, 110, 80, 70, 80, 50, 0],
#  677: [70, 50, 30, 95, 135, 105, 0],
#  678: [50, 40, 85, 40, 65, 25, 0],
#  679: [80, 70, 40, 100, 60, 145, 0],
#  680: [109, 66, 84, 81, 99, 32, 0],
#  681: [45, 85, 50, 55, 50, 65, 0],
#  682: [65, 125, 60, 95, 60, 105, 0],
#  683: [77, 120, 90, 60, 90, 48, 0],
#  684: [59, 74, 50, 35, 50, 35, 0],
#  685: [89, 124, 80, 55, 80, 55, 0],
#  686: [45, 85, 70, 40, 40, 60, 0],
#  687: [65, 125, 100, 60, 70, 70, 0],
#  688: [95, 110, 95, 40, 95, 55, 0],
#  689: [70, 83, 50, 37, 50, 60, 0],
#  690: [100, 123, 75, 57, 75, 80, 0],
#  691: [70, 55, 75, 45, 65, 60, 0],
#  692: [110, 65, 105, 55, 95, 80, 0],
#  693: [85, 97, 66, 105, 66, 65, 0],
#  694: [58, 109, 112, 48, 48, 109, 0],
#  695: [52, 65, 50, 45, 50, 38, 0],
#  696: [72, 85, 70, 65, 70, 58, 0],
#  697: [92, 105, 90, 125, 90, 98, 0],
#  698: [55, 85, 55, 50, 55, 60, 0],
#  699: [85, 60, 65, 135, 105, 100, 0],
#  700: [91, 90, 129, 90, 72, 108, 1],
#  701: [91, 129, 90, 72, 90, 108, 1],
#  702: [91, 90, 72, 90, 129, 108, 1],
#  703: [79, 115, 70, 125, 80, 111, 1],
#  704: [79, 100, 80, 110, 90, 121, 1],
#  705: [79, 115, 70, 125, 80, 111, 1],
#  706: [79, 105, 70, 145, 80, 101, 1],
#  707: [100, 120, 100, 150, 120, 90, 1],
#  708: [100, 150, 120, 120, 100, 90, 1],
#  709: [89, 125, 90, 115, 80, 101, 1],
#  710: [89, 145, 90, 105, 80, 91, 1],
#  711: [125, 130, 90, 130, 90, 95, 1],
#  712: [125, 170, 100, 120, 90, 95, 1],
#  713: [125, 120, 90, 170, 100, 95, 1],
#  714: [91, 72, 90, 129, 90, 108, 0],
#  715: [91, 72, 90, 129, 90, 108, 0],
#  716: [100, 77, 77, 128, 128, 90, 0],
#  717: [100, 128, 90, 77, 77, 128, 0],
#  718: [71, 120, 95, 120, 95, 99, 0],
#  719: [56, 61, 65, 48, 45, 38, 0],
#  720: [61, 78, 95, 56, 58, 57, 0],
#  721: [88, 107, 122, 74, 75, 64, 0],
#  722: [40, 45, 40, 62, 60, 60, 0],
#  723: [59, 59, 58, 90, 70, 73, 0],
#  724: [75, 69, 72, 114, 100, 104, 0],
#  725: [41, 56, 40, 62, 44, 71, 0],
#  726: [54, 63, 52, 83, 56, 97, 0],
#  727: [72, 95, 67, 103, 71, 122, 0],
#  728: [38, 36, 38, 32, 36, 57, 0],
#  729: [85, 56, 77, 50, 77, 78, 0],
#  730: [45, 50, 43, 40, 38, 62, 0],
#  731: [62, 73, 55, 56, 52, 84, 0],
#  732: [78, 81, 71, 74, 69, 126, 0],
#  733: [38, 35, 40, 27, 25, 35, 0],
#  734: [45, 22, 60, 27, 30, 29, 0],
#  735: [80, 52, 50, 90, 50, 89, 0],
#  736: [62, 50, 58, 73, 54, 72, 0],
#  737: [86, 68, 72, 109, 66, 106, 0],
#  738: [44, 38, 39, 61, 79, 42, 0],
#  739: [54, 45, 47, 75, 98, 52, 0],
#  740: [78, 65, 68, 112, 154, 75, 0],
#  741: [66, 65, 48, 62, 57, 52, 0],
#  742: [123, 100, 62, 97, 81, 68, 0],
#  743: [67, 82, 62, 46, 48, 43, 0],
#  744: [95, 124, 78, 69, 71, 58, 0],
#  745: [75, 80, 60, 65, 90, 102, 0],
#  746: [62, 48, 54, 63, 60, 68, 0],
#  747: [74, 48, 76, 83, 81, 104, 0],
#  748: [74, 48, 76, 83, 81, 104, 0],
#  749: [45, 80, 100, 35, 37, 28, 0],
#  750: [59, 110, 150, 45, 49, 35, 0],
#  751: [60, 150, 50, 150, 50, 60, 0],
#  752: [60, 50, 150, 50, 150, 60, 0],
#  753: [78, 52, 60, 63, 65, 23, 0],
#  754: [101, 72, 72, 99, 89, 29, 0],
#  755: [62, 48, 66, 59, 57, 49, 0],
#  756: [82, 80, 86, 85, 75, 72, 0],
#  757: [53, 54, 53, 37, 46, 45, 0],
#  758: [86, 92, 88, 68, 75, 73, 0],
#  759: [42, 52, 67, 39, 56, 50, 0],
#  760: [72, 105, 115, 54, 86, 68, 0],
#  761: [50, 60, 60, 60, 60, 30, 0],
#  762: [65, 75, 90, 97, 123, 44, 0],
#  763: [50, 53, 62, 58, 63, 44, 0],
#  764: [71, 73, 88, 120, 89, 59, 0],
#  765: [44, 38, 33, 61, 43, 70, 0],
#  766: [62, 55, 52, 109, 94, 109, 0],
#  767: [58, 89, 77, 45, 45, 48, 0],
#  768: [82, 121, 119, 69, 59, 71, 0],
#  769: [77, 59, 50, 67, 63, 46, 0],
#  770: [123, 77, 72, 99, 92, 58, 0],
#  771: [95, 65, 65, 110, 130, 60, 0],
#  772: [78, 92, 75, 74, 63, 118, 0],
#  773: [67, 58, 57, 81, 67, 101, 0],
#  774: [50, 50, 150, 50, 150, 50, 0],
#  775: [45, 50, 35, 55, 75, 40, 0],
#  776: [68, 75, 53, 83, 113, 60, 0],
#  777: [90, 100, 70, 110, 150, 80, 0],
#  778: [57, 80, 91, 80, 87, 75, 0],
#  779: [43, 70, 48, 50, 60, 38, 0],
#  780: [85, 110, 76, 65, 82, 56, 0],
#  781: [49, 66, 70, 44, 55, 51, 0],
#  782: [44, 66, 70, 44, 55, 56, 0],
#  783: [54, 66, 70, 44, 55, 46, 0],
#  784: [59, 66, 70, 44, 55, 41, 0],
#  785: [65, 90, 122, 58, 75, 84, 0],
#  786: [55, 85, 122, 58, 75, 99, 0],
#  787: [75, 95, 122, 58, 75, 69, 0],
#  788: [85, 100, 122, 58, 75, 54, 0],
#  789: [55, 69, 85, 32, 35, 28, 0],
#  790: [95, 117, 184, 44, 46, 28, 0],
#  791: [40, 30, 35, 45, 40, 55, 0],
#  792: [85, 70, 80, 97, 80, 123, 0],
#  793: [126, 131, 95, 131, 98, 99, 1],
#  794: [126, 131, 95, 131, 98, 99, 1],
#  795: [108, 100, 121, 81, 95, 95, 1],
#  796: [50, 100, 150, 100, 150, 50, 1],
#  797: [50, 160, 110, 160, 110, 110, 1],
#  798: [80, 110, 60, 150, 130, 70, 1],
#  799: [80, 160, 60, 170, 130, 80, 1],
#  800: [80, 110, 120, 130, 90, 70, 1]}

# %%
combats.Winner[combats.Winner == combats.First_pokemon] = 0
combats.Winner[combats.Winner == combats.Second_pokemon] = 1

print(combats.head(5))
# Out:
#    First_pokemon  Second_pokemon  Winner
# 0            266             298       1
# 1            702             701       1
# 2            191             668       1
# 3            237             683       1
# 4            151             231       0

# %%
def replace_things(data):
    #map each battles to pokemon data
    
    data['First_pokemon_stats'] = data.First_pokemon.map(stats_dict)
    data['Second_pokemon_stats'] = data.Second_pokemon.map(stats_dict)

    data['First_pokemon'] = data.First_pokemon.map(type_dict)
    data['Second_pokemon'] = data.Second_pokemon.map(type_dict)

    return data

# %%
def calculate_stats(data):
    #calculate stats difference
    
    stats_col = ['HP_diff', 'Attack_diff', 'Defense_diff', 'Sp.Atk_diff', 'Sp.Def_diff', 'Speed_diff', 'Legendary_diff']
    diff_list = []

    for row in data.itertuples():
        diff_list.append(np.array(row.First_pokemon_stats) - np.array(row.Second_pokemon_stats))

    stats_df = pd.DataFrame(diff_list, columns=stats_col)
    data = pd.concat([data, stats_df], axis=1)
    data.drop(['First_pokemon_stats', 'Second_pokemon_stats'], axis=1, inplace=True)

    return data

# %%
def calculate_effectiveness(data):
    '''
        This function creates a new column of each pokemon's effectiveness against it's enemy.
        every effectiveness starts with 1, if an effective type is found on enemy's type, effectiveness * 2
        if not very effective is found on enemy's type, effectiveness / 2
        if not effective is found on enemy's type, effectiveness * 0
        
        This function creates 4 new columns
            1. P1_type1, pokemon 1 first type effectiveness against the enemy's type
            2. P1_type2, pokemon 1 second type effectiveness against the enemy's type
            3. P2_type1, pokemon 2 first type effectiveness against the enemy's type
            4. P2_type2, pokemon 2 second type effectiveness against the enemy's type
    '''
    
    very_effective_dict = {'Normal': ["Non"],
                           'Fighting': ['Normal', 'Rock', 'Steel', 'Ice', 'Dark'],
                           'Flying': ['Fighting', 'Bug', 'Grass'],
                           'Poison': ['Grass', 'Fairy'],
                           'Ground': ['Poison', 'Rock', 'Steel', 'Fire', 'Electric'],
                           'Rock': ['Flying', 'Bug', 'Fire', 'Ice'],
                           'Bug': ['Grass', 'Psychic', 'Dark'],
                           'Ghost': ['Ghost', 'Psychic'],
                           'Steel': ['Rock', 'Ice', 'Fairy'],
                           'Fire': ['Bug', 'Steel', 'Grass', 'Ice'],
                           'Water': ['Ground', 'Rock', 'Fire'],
                           'Grass': ['Ground', 'Rock', 'Water'],
                           'Electric': ['Flying', 'Water'],
                           'Psychic': ['Fighting', 'Poison'],
                           'Ice': ['Flying', 'Ground', 'Grass', 'Dragon'],
                           'Dragon': ['Dragon'],
                           'Dark': ['Ghost', 'Psychic'],
                           'Fairy': ['Fighting', 'Dragon', 'Dark'],
                           'None': ["Non"]}

    not_very_effective_dict = {'Normal': ['Rock', 'Steel'],
                               'Fighting': ['Flying', 'Poison', 'Bug', 'Psychic', 'Fairy'],
                               'Flying': ['Rock', 'Steel', 'Electric'],
                               'Poison': ['Poison', 'Rock', 'Ground', 'Ghost'],
                               'Ground': ['Bug', 'Grass'],
                               'Rock': ['Fighting', 'Ground', 'Steel'],
                               'Bug': ['Fighting', 'Flying', 'Poison', 'Ghost', 'Steel', 'Fire', 'Fairy'],
                               'Ghost': ['Dark'],
                               'Steel': ['Steel', 'Fire', 'Water', 'Electric'],
                               'Fire': ['Rock', 'Fire', 'Water', 'Dragon'],
                               'Water': ['Water', 'Grass', 'Dragon'],
                               'Grass': ['Flying', 'Poison', 'Bug', 'Steel', 'Fire', 'Grass', 'Dragon'],
                               'Electric': ['Grass', 'Electric', 'Dragon'],
                               'Psychic': ['Steel', 'Psychic'],
                               'Ice': ['Steel', 'Fire', 'Water', 'Psychic'],
                               'Dragon': ['Steel'],
                               'Dark': ['Fighting', 'Dark', 'Fairy'],
                               'Fairy': ['Poison', 'Steel', 'Fire'],
                               'None': ["Non"]}

    not_effective_dict = {'Normal': ['Ghost'],
                          'Fighting': ['Ghost'],
                          'Flying': ["Non"],
                          'Poison': ['Steel'],
                          'Ground': ['Flying'],
                          'Rock': ["Non"],
                          'Bug': ["Non"],
                          'Ghost': ['Normal'],
                          'Steel': ["Non"],
                          'Fire': ["Non"],
                          'Water': ["Non"],
                          'Grass': ["Non"],
                          'Electric': ['Ground'],
                          'Psychic': ['Dark'],
                          'Ice': ["Non"],
                          'Dragon': ['Fairy'],
                          'Dark': ["Non"],
                          'Fairy': ["Non"],
                          'None': ["Non"]}

    p1_type1_list = []
    p1_type2_list = []
    p2_type1_list = []
    p2_type2_list = []

    for row in data.itertuples():
        nested_type = [[1, 1], [1, 1]]

        # Manipulating values if found on dictionary
        for i in range(0,2):
            for j in range(0,2):
                if row.Second_pokemon[j] in very_effective_dict.get(row.First_pokemon[i]):
                    nested_type[0][i] *= 2
                if row.Second_pokemon[j] in not_very_effective_dict.get(row.First_pokemon[i]):
                    nested_type[0][i] /= 2
                if row.Second_pokemon[j] in not_effective_dict.get(row.First_pokemon[i]):
                    nested_type[0][i] *= 0

                if row.First_pokemon[j] in very_effective_dict.get(row.Second_pokemon[i]):
                    nested_type[1][i] *= 2
                if row.First_pokemon[j] in not_very_effective_dict.get(row.Second_pokemon[i]):
                    nested_type[1][i] /= 2
                if row.First_pokemon[j] in not_effective_dict.get(row.Second_pokemon[i]):
                    nested_type[1][i] *= 0

        p1_type1_list.append(nested_type[0][0])
        p1_type2_list.append(nested_type[0][1])
        p2_type1_list.append(nested_type[1][0])
        p2_type2_list.append(nested_type[1][1])
        

    data = data.assign(P1_type1=p1_type1_list, P1_type2=p1_type2_list, P2_type1=p2_type1_list, P2_type2=p2_type2_list)
    data = data.drop(['First_pokemon', 'Second_pokemon'], axis=1)

    return data

# %%
train_df = replace_things(combats)
print(train_df.head(5))
print('Les valeurs de la liste correspondent, dans l\'ordre, aux Points de Vie, à l\'Attaque, à la Défense, à l\'Attaque Spéciale, à la Défense Spéciale, à la Vitesse et au statut de Pokémon légendaire')
# Out:
#        First_pokemon    Second_pokemon  Winner            First_pokemon_stats  \
# 0     [Rock, Ground]     [Grass, Dark]       1    [50, 64, 50, 45, 50, 41, 0]
# 1  [Grass, Fighting]  [Rock, Fighting]       1  [91, 90, 72, 90, 129, 108, 1]
# 2    [Fairy, Flying]   [Psychic, None]       1   [55, 40, 85, 80, 105, 40, 0]
# 3       [Fire, None]    [Dragon, None]       1    [40, 40, 40, 70, 40, 20, 0]
# 4      [Rock, Water]       [Bug, Rock]       0  [70, 60, 125, 115, 70, 55, 0]
#
#             Second_pokemon_stats
# 0    [70, 70, 40, 60, 40, 60, 0]
# 1  [91, 129, 90, 72, 90, 108, 1]
# 2   [75, 75, 75, 125, 95, 40, 0]
# 3   [77, 120, 90, 60, 90, 48, 0]
# 4   [20, 10, 230, 10, 230, 5, 0]
# Les valeurs de la liste correspondent, dans l'ordre, aux Points de Vie, à l'Attaque, à la Défense, à l'Attaque Spéciale, à la Défense Spéciale, à la Vitesse et au statut de Pokémon légendaire

# %%
train_df = calculate_stats(train_df)
print(train_df.head(1))
# Out:
#     First_pokemon Second_pokemon  Winner  HP_diff  Attack_diff  Defense_diff  \
# 0  [Rock, Ground]  [Grass, Dark]       1      -20           -6            10
#
#    Sp.Atk_diff  Sp.Def_diff  Speed_diff  Legendary_diff
# 0          -15           10         -19               0

# %%
train_df = calculate_effectiveness(train_df)
print(train_df.head(1))
# Out:
#    Winner  HP_diff  Attack_diff  Defense_diff  Sp.Atk_diff  Sp.Def_diff  \
# 0       1      -20           -6            10          -15           10
#
#    Speed_diff  Legendary_diff  P1_type1  P1_type2  P2_type1  P2_type2
# 0         -19               0       1.0       0.5       4.0       1.0

# %% [markdown]
# # Machine Learning

# %%
y_train_full = train_df['Winner']
x_train_full = train_df.drop('Winner', axis=1)

x_train, x_cv, y_train, y_cv = train_test_split(x_train_full, y_train_full, test_size=0.2, random_state=42)

# %%
clf_dict = {'log reg': LogisticRegression(), 
            'naive bayes': GaussianNB(), 
            'random forest': RandomForestClassifier(n_estimators=100),
            'knn': KNeighborsClassifier(),
            'linear svc': LinearSVC(),
            'ada boost': AdaBoostClassifier(n_estimators=100),
            'gradient boosting': GradientBoostingClassifier(n_estimators=100),
            'CART': DecisionTreeClassifier()}

# %%
for name, clf in clf_dict.items():
    model = clf.fit(x_train, y_train)
    pred = model.predict(x_cv)
    print('Accuracy of {}:'.format(name), accuracy_score(pred, y_cv))
# Out:
# /home/marmouset/Documents/api_model/env/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Accuracy of log reg: 0.8816
# Accuracy of naive bayes: 0.8102
# Accuracy of random forest: 0.9621
# Accuracy of knn: 0.9056
# /home/marmouset/Documents/api_model/env/lib/python3.10/site-packages/sklearn/svm/_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Accuracy of linear svc: 0.7529
# Accuracy of ada boost: 0.9463
# Accuracy of gradient boosting: 0.9564
# Accuracy of CART: 0.9439

# %%
classifier = RandomForestClassifier(n_estimators=100)
model = classifier.fit(x_train_full, y_train_full)

# %%
test_df = replace_things(tests)

# %%
print(test_df.head(5))
# Out:
#         First_pokemon    Second_pokemon             First_pokemon_stats  \
# 0       [Water, None]    [Normal, None]     [80, 92, 65, 65, 80, 68, 0]
# 1      [Grass, Steel]   [Water, Ground]   [74, 94, 131, 54, 116, 20, 0]
# 2  [Electric, Flying]  [Fighting, None]  [79, 105, 70, 145, 80, 101, 1]
# 3    [Electric, None]     [Grass, None]     [70, 55, 55, 80, 60, 45, 0]
# 4    [Normal, Flying]     [Water, None]     [40, 60, 30, 31, 31, 70, 0]
#
#             Second_pokemon_stats
# 0    [90, 55, 75, 60, 75, 30, 0]
# 1    [95, 85, 85, 65, 65, 35, 0]
# 2  [50, 120, 53, 35, 110, 87, 0]
# 3   [75, 86, 67, 106, 67, 60, 0]
# 4   [165, 75, 80, 40, 45, 65, 0]

# %%
test_df = calculate_stats(test_df)
test_df = calculate_effectiveness(test_df)
prediction = model.predict(test_df)

# %%
prediction
# Out:
# array([0, 1, 0, ..., 0, 0, 1])

# %%
prediction_df['Winner'] = prediction
#prediction_df['First_pokemon'] = prediction_df['First_pokemon'].map(name_dict)
#prediction_df['Second_pokemon'] = prediction_df['Second_pokemon'].map(name_dict)

prediction_df['Winner'][prediction_df['Winner'] == 0] = prediction_df['First_pokemon']
prediction_df['Winner'][prediction_df['Winner'] == 1] = prediction_df['Second_pokemon']
print(prediction_df)
# Out:
#       First_pokemon  Second_pokemon  Winner
# 0               129             117     129
# 1               660             211     211
# 2               706             115     706
# 3               195             618     618
# 4                27             656      27
# ...             ...             ...     ...
# 9995            216             498     498
# 9996            113             404     404
# 9997            493             104     493
# 9998            643             259     643
# 9999            678             531     531
#
# [10000 rows x 3 columns]
